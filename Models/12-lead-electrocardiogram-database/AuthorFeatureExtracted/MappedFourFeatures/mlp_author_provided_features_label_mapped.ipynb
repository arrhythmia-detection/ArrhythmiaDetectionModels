# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping

# Load the Diagnostics.xlsx data
diagnostics_file = "../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"
diagnostics_df = pd.read_excel(diagnostics_file)

# Rename "SA" to "SI" in the "Rhythm" column
diagnostics_df["Rhythm"] = diagnostics_df["Rhythm"].replace("SA", "SI")

# Drop rows with any missing values
diagnostics_df = diagnostics_df.dropna()

# Encode "Gender" column: 0 for "MALE" and 1 for "FEMALE"
diagnostics_df["Gender"] = diagnostics_df["Gender"].map({"MALE": 0, "FEMALE": 1})

# Merge specified labels
merge_mapping = {
    "AF": "AFIB", "AFIB": "AFIB",
    "SVT": "GSVT", "AT": "GSVT", "SAAWR": "GSVT", "ST": "GSVT", "AVNRT": "GSVT", "AVRT": "GSVT",
    "SB": "SB",
    "SR": "SR", "SI": "SR"
}
diagnostics_df["Rhythm"] = diagnostics_df["Rhythm"].map(merge_mapping)

# Separate features and labels
features = diagnostics_df.drop(columns=["FileName", "Rhythm", "Beat"]).values
labels = diagnostics_df["Rhythm"].values  # Using "Rhythm" as the target variable

# Convert features to float32
features = features.astype("float32")

# Encode labels as one-hot with merged classes
unique_labels = np.unique(labels)
label_map = {label: index for index, label in enumerate(unique_labels)}
labels_encoded = to_categorical([label_map[label] for label in labels])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, labels_encoded, test_size=0.2, random_state=42)
# Out:
# 2024-11-08 22:19:23.645614: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-08 22:19:23.656447: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-08 22:19:23.659728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-08 22:19:23.671095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-08 22:19:24.253566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Define the MLP model
model = Sequential([
    Dense(32, activation="relu", input_shape=(X_train.shape[1],)),
    Dense(16, activation="relu"),
    Dense(labels_encoded.shape[1], activation="softmax")  # Output layer with the number of merged classes
])

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Set up early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, batch_size=1024, callbacks=[early_stopping])

# Evaluate the model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Map back to original labels for a readable report
label_names = [label for label, index in sorted(label_map.items(), key=lambda item: item[1])]
print("\nClassification Report:\n")
print(classification_report(y_test_classes, y_pred_classes, target_names=label_names))
# Out:
# Epoch 1/200
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-11-08 22:21:22.777102: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_328', 408 bytes spill stores, 452 bytes spill loads
#
# 2024-11-08 22:21:22.839174: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_326', 32 bytes spill stores, 32 bytes spill loads
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - accuracy: 0.2157 - loss: 147.4465 - val_accuracy: 0.2948 - val_loss: 86.4828
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2487 - loss: 79.7812 - val_accuracy: 0.3526 - val_loss: 61.4352
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3575 - loss: 57.9095 - val_accuracy: 0.2516 - val_loss: 42.8619
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2721 - loss: 39.9373 - val_accuracy: 0.4380 - val_loss: 28.0387
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4172 - loss: 26.2236 - val_accuracy: 0.3775 - val_loss: 14.7852
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4272 - loss: 12.4288 - val_accuracy: 0.3676 - val_loss: 6.3875
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4245 - loss: 6.7714 - val_accuracy: 0.4718 - val_loss: 7.5307
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4916 - loss: 6.4801 - val_accuracy: 0.5610 - val_loss: 5.0928
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5754 - loss: 5.1164 - val_accuracy: 0.6244 - val_loss: 4.6531
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6087 - loss: 4.5751 - val_accuracy: 0.5897 - val_loss: 4.1826
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6069 - loss: 4.0201 - val_accuracy: 0.6418 - val_loss: 3.7285
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6455 - loss: 3.5779 - val_accuracy: 0.6531 - val_loss: 3.4169
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6529 - loss: 3.2990 - val_accuracy: 0.6587 - val_loss: 3.0737
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6559 - loss: 2.8113 - val_accuracy: 0.6657 - val_loss: 2.7890
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6714 - loss: 2.6051 - val_accuracy: 0.6695 - val_loss: 2.5005
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6770 - loss: 2.3122 - val_accuracy: 0.6728 - val_loss: 2.2756
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6861 - loss: 2.0317 - val_accuracy: 0.6892 - val_loss: 2.0657
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6790 - loss: 1.8695 - val_accuracy: 0.6944 - val_loss: 1.9164
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6950 - loss: 1.7465 - val_accuracy: 0.6991 - val_loss: 1.7911
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7004 - loss: 1.5880 - val_accuracy: 0.7122 - val_loss: 1.6779
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7112 - loss: 1.5502 - val_accuracy: 0.7070 - val_loss: 1.6006
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7142 - loss: 1.4816 - val_accuracy: 0.7005 - val_loss: 1.5448
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7126 - loss: 1.3537 - val_accuracy: 0.7258 - val_loss: 1.4262
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7209 - loss: 1.2732 - val_accuracy: 0.7249 - val_loss: 1.3626
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7249 - loss: 1.2091 - val_accuracy: 0.7315 - val_loss: 1.2946
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7375 - loss: 1.1267 - val_accuracy: 0.7385 - val_loss: 1.2272
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7274 - loss: 1.0904 - val_accuracy: 0.7239 - val_loss: 1.1829
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7327 - loss: 1.0162 - val_accuracy: 0.7479 - val_loss: 1.1107
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7440 - loss: 0.9688 - val_accuracy: 0.7559 - val_loss: 1.0727
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7534 - loss: 0.9200 - val_accuracy: 0.7498 - val_loss: 1.0084
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7545 - loss: 0.8998 - val_accuracy: 0.7577 - val_loss: 0.9734
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - loss: 0.8517 - val_accuracy: 0.7587 - val_loss: 0.9312
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7602 - loss: 0.8109 - val_accuracy: 0.7606 - val_loss: 0.9007
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7571 - loss: 0.8068 - val_accuracy: 0.7620 - val_loss: 0.8807
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7641 - loss: 0.7668 - val_accuracy: 0.7648 - val_loss: 0.8437
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7590 - loss: 0.7612 - val_accuracy: 0.7516 - val_loss: 0.8490
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7581 - loss: 0.7577 - val_accuracy: 0.7718 - val_loss: 0.7983
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7787 - loss: 0.7082 - val_accuracy: 0.7676 - val_loss: 0.7963
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7781 - loss: 0.6924 - val_accuracy: 0.7732 - val_loss: 0.7666
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7811 - loss: 0.6933 - val_accuracy: 0.7765 - val_loss: 0.7447
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - loss: 0.6455 - val_accuracy: 0.7714 - val_loss: 0.7450
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7811 - loss: 0.6359 - val_accuracy: 0.7502 - val_loss: 0.7626
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7760 - loss: 0.6717 - val_accuracy: 0.7775 - val_loss: 0.7096
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.6167 - val_accuracy: 0.8028 - val_loss: 0.6879
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8000 - loss: 0.5987 - val_accuracy: 0.7995 - val_loss: 0.6701
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7955 - loss: 0.6041 - val_accuracy: 0.7723 - val_loss: 0.6884
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.5840 - val_accuracy: 0.7995 - val_loss: 0.6565
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.5691 - val_accuracy: 0.7915 - val_loss: 0.6871
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.5948 - val_accuracy: 0.8089 - val_loss: 0.6370
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - loss: 0.5617 - val_accuracy: 0.7737 - val_loss: 0.6762
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7984 - loss: 0.5798 - val_accuracy: 0.8042 - val_loss: 0.6307
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7969 - loss: 0.5637 - val_accuracy: 0.8131 - val_loss: 0.6267
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8152 - loss: 0.5362 - val_accuracy: 0.7977 - val_loss: 0.6232
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8074 - loss: 0.5389 - val_accuracy: 0.8061 - val_loss: 0.6132
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.5483 - val_accuracy: 0.8056 - val_loss: 0.6143
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8131 - loss: 0.5184 - val_accuracy: 0.8000 - val_loss: 0.6123
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8063 - loss: 0.5142 - val_accuracy: 0.7930 - val_loss: 0.6324
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8065 - loss: 0.5254 - val_accuracy: 0.8117 - val_loss: 0.5901
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8134 - loss: 0.5067 - val_accuracy: 0.8178 - val_loss: 0.5850
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8201 - loss: 0.5107 - val_accuracy: 0.8183 - val_loss: 0.6010
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8173 - loss: 0.5088 - val_accuracy: 0.8160 - val_loss: 0.5881
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8189 - loss: 0.4922 - val_accuracy: 0.8155 - val_loss: 0.5760
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8174 - loss: 0.4942 - val_accuracy: 0.7939 - val_loss: 0.6019
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8098 - loss: 0.4982 - val_accuracy: 0.7930 - val_loss: 0.5984
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7985 - loss: 0.5148 - val_accuracy: 0.8239 - val_loss: 0.5640
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8193 - loss: 0.4848 - val_accuracy: 0.8216 - val_loss: 0.5590
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8179 - loss: 0.4864 - val_accuracy: 0.8174 - val_loss: 0.5604
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8227 - loss: 0.4618 - val_accuracy: 0.8216 - val_loss: 0.5543
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8236 - loss: 0.4845 - val_accuracy: 0.8216 - val_loss: 0.5516
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8208 - loss: 0.4782 - val_accuracy: 0.8080 - val_loss: 0.5599
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8209 - loss: 0.4796 - val_accuracy: 0.7981 - val_loss: 0.5789
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8257 - loss: 0.4775 - val_accuracy: 0.8291 - val_loss: 0.5510
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8256 - loss: 0.4770 - val_accuracy: 0.8296 - val_loss: 0.5466
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8260 - loss: 0.4773 - val_accuracy: 0.8225 - val_loss: 0.5465
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8287 - loss: 0.4606 - val_accuracy: 0.8202 - val_loss: 0.5459
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8251 - loss: 0.4674 - val_accuracy: 0.8216 - val_loss: 0.5415
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8231 - loss: 0.4657 - val_accuracy: 0.7977 - val_loss: 0.5845
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8203 - loss: 0.4777 - val_accuracy: 0.8146 - val_loss: 0.5426
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8199 - loss: 0.4805 - val_accuracy: 0.8333 - val_loss: 0.5388
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8257 - loss: 0.4778 - val_accuracy: 0.8178 - val_loss: 0.5505
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8294 - loss: 0.4567 - val_accuracy: 0.8160 - val_loss: 0.5471
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.4680 - val_accuracy: 0.8197 - val_loss: 0.5334
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8224 - loss: 0.4713 - val_accuracy: 0.8254 - val_loss: 0.5310
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8229 - loss: 0.4695 - val_accuracy: 0.8066 - val_loss: 0.5440
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8291 - loss: 0.4648 - val_accuracy: 0.8005 - val_loss: 0.5548
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8084 - loss: 0.5001 - val_accuracy: 0.8155 - val_loss: 0.5365
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8233 - loss: 0.4528 - val_accuracy: 0.8070 - val_loss: 0.5652
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8236 - loss: 0.4598 - val_accuracy: 0.8070 - val_loss: 0.5560
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         AFIB       0.61      0.64      0.62       424
#         GSVT       0.81      0.72      0.76       482
#           SB       0.94      0.98      0.96       777
#           SR       0.84      0.84      0.84       447
#
#     accuracy                           0.83      2130
#    macro avg       0.80      0.80      0.80      2130
# weighted avg       0.82      0.83      0.82      2130
