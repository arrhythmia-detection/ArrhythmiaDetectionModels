# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

from biosppy.signals import ecg

# Randomly seeding
tf.random.set_seed(6950)

# Constants
SAMPLING_RATE = 500  # Hz
ecg_folder = "../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}


# Feature extraction function
def extract_comprehensive_features(ecg_signal):
    try:
        ecg_processed = ecg.ecg(signal=ecg_signal, sampling_rate=SAMPLING_RATE, show=False)
        rpeaks = ecg_processed['rpeaks']
        heart_rate = ecg_processed['heart_rate']

        features = [
            np.mean(ecg_signal),
            np.std(ecg_signal),
            np.median(ecg_signal),
            np.min(ecg_signal),
            np.max(ecg_signal),
            len(rpeaks),
            np.mean(heart_rate) if len(heart_rate) > 0 else 0,
            np.std(heart_rate) if len(heart_rate) > 0 else 0,
            np.mean(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.std(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.percentile(ecg_signal, 25),
            np.percentile(ecg_signal, 75),
        ]
        return features
    except Exception as e:
        print(f"Error processing signal: {e}")
        return [0] * 12


# Dataset preparation function
def prepare_dataset(ecg_folder, diagnostics_df):
    signals, signal_features, signal_labels = [], [], []

    for _, row in diagnostics_df.iterrows():
        file_name = row['FileName']
        rhythm_label = row['Rhythm']
        patient_age = row['PatientAge']
        gender = row['Gender']

        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            continue

        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            continue

        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)

        features = extract_comprehensive_features(ecg_data)

        # Append age and gender as additional features
        features.append(patient_age)
        features.append(gender)

        signals.append(ecg_data)
        signal_features.append(features)
        signal_labels.append(rhythm_label)

    return np.array(signals), np.array(signal_features), np.array(signal_labels)


# Load and process data
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)

# Encode gender (binary: 'Male' or 'Female')
gender_encoder = LabelEncoder()
diagnostics_df['Gender'] = gender_encoder.fit_transform(diagnostics_df['Gender'])

raw_signals, signal_features, signal_labels = prepare_dataset(ecg_folder, diagnostics_df)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(signal_labels)
onehot_labels = to_categorical(encoded_labels)

feature_scaler = StandardScaler()
scaled_features = feature_scaler.fit_transform(signal_features)


# Create MLP model
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model


# Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = []

for train_index, test_index in skf.split(scaled_features, encoded_labels):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = onehot_labels[train_index], onehot_labels[test_index]

    # Plot class distribution
    unique, counts = np.unique(np.argmax(y_train, axis=1), return_counts=True)
    plt.bar(label_encoder.classes_, counts)
    plt.xlabel("Classes")
    plt.ylabel("Number of Samples")
    plt.title("Class Distribution in Training Set")
    plt.show()

    model = create_mlp_model(input_shape=X_train.shape[1], num_classes=onehot_labels.shape[1])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
    _, accuracy = model.evaluate(X_test, y_test, verbose=0)
    cv_scores.append(accuracy)

    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    print("\nClassification Report:")
    print(classification_report(y_test_classes, y_pred_classes, target_names=label_encoder.classes_, digits=5))

# Print results
print(f"\nMean Cross-Validation Accuracy: {np.mean(cv_scores):.2f}")
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732847301.481800  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.512770  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.515754  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.519125  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.522739  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.524630  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.630782  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.632048  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732847301.633311  464681 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-29 08:28:21.634349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5436 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732847302.312825  468389 service.cc:146] XLA service 0x77b670004da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732847302.312854  468389 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-11-29 08:28:22.345634: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-29 08:28:22.464411: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 144/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6578 - loss: 0.8718
# I0000 00:00:1732847303.538838  468389 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.6969 - loss: 0.7855 - val_accuracy: 0.8550 - val_loss: 0.4746
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.8842 - loss: 0.3705 - val_accuracy: 0.7940 - val_loss: 0.5610
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.8850 - loss: 0.3342 - val_accuracy: 0.6931 - val_loss: 0.7699
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9042 - loss: 0.2830 - val_accuracy: 0.7617 - val_loss: 0.5997
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.8987 - loss: 0.2835 - val_accuracy: 0.6743 - val_loss: 0.8549
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9140 - loss: 0.2560 - val_accuracy: 0.7353 - val_loss: 0.6853
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.9172 - loss: 0.2416 - val_accuracy: 0.6896 - val_loss: 0.7842
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.9177 - loss: 0.2402 - val_accuracy: 0.7424 - val_loss: 0.6602
# Epoch 9/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9184 - loss: 0.2387 - val_accuracy: 0.7424 - val_loss: 0.6328
# Epoch 10/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9275 - loss: 0.2123 - val_accuracy: 0.6502 - val_loss: 1.0862
# Epoch 11/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.9242 - loss: 0.2259 - val_accuracy: 0.6567 - val_loss: 0.9916
# Epoch 12/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.9289 - loss: 0.2115 - val_accuracy: 0.6197 - val_loss: 1.2339
# Epoch 13/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.9343 - loss: 0.1936 - val_accuracy: 0.6749 - val_loss: 0.7590
# Epoch 14/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9255 - loss: 0.2075 - val_accuracy: 0.6444 - val_loss: 0.9766
# Epoch 15/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9320 - loss: 0.2000 - val_accuracy: 0.6995 - val_loss: 0.7514
# Epoch 16/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.9335 - loss: 0.1900 - val_accuracy: 0.6714 - val_loss: 0.8582
# Epoch 17/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.9350 - loss: 0.1920 - val_accuracy: 0.6702 - val_loss: 0.7951
# Epoch 18/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.9353 - loss: 0.1876 - val_accuracy: 0.6367 - val_loss: 1.1446
# Epoch 19/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0
100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.9531 - loss: 0.1270 - val_accuracy: 0.6303 - val_loss: 1.4845
# Epoch 84/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.9551 - loss: 0.1221 - val_accuracy: 0.6749 - val_loss: 1.1170
# Epoch 85/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.9536 - loss: 0.1296 - val_accuracy: 0.6825 - val_loss: 1.2169
# Epoch 86/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9574 - loss: 0.1161 - val_accuracy: 0.7218 - val_loss: 1.0157
# Epoch 87/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.9524 - loss: 0.1398 - val_accuracy: 0.6696 - val_loss: 1.3659
# Epoch 88/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.9482 - loss: 0.1390 - val_accuracy: 0.6403 - val_loss: 1.4960
# Epoch 89/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.9504 - loss: 0.1297 - val_accuracy: 0.7060 - val_loss: 1.1235
# Epoch 90/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9558 - loss: 0.1267 - val_accuracy: 0.6461 - val_loss: 1.4134
# Epoch 91/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.9558 - loss: 0.1258 - val_accuracy: 0.6708 - val_loss: 1.2735
# Epoch 92/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9555 - loss: 0.1200 - val_accuracy: 0.6837 - val_loss: 1.2597
# Epoch 93/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9548 - loss: 0.1261 - val_accuracy: 0.6719 - val_loss: 1.4521
# Epoch 94/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.9544 - loss: 0.1302 - val_accuracy: 0.6878 - val_loss: 1.3844
# Epoch 95/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9539 - loss: 0.1251 - val_accuracy: 0.6485 - val_loss: 1.5488
# Epoch 96/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9537 - loss: 0.1202 - val_accuracy: 0.7019 - val_loss: 1.1899
# Epoch 97/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9565 - loss: 0.1141 - val_accuracy: 0.6884 - val_loss: 1.1548
# Epoch 98/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9559 - loss: 0.1249 - val_accuracy: 0.6913 - val_loss: 1.2676
# Epoch 99/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9602 - loss: 0.1118 - val_accuracy: 0.6585 - val_loss: 1.4969
# Epoch 100/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9590 - loss: 0.1163 - val_accuracy: 0.6690 - val_loss: 1.3651
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.73      0.88      0.80       445
#         GSVT       0.92      0.71      0.80       462
#           SB       0.97      0.98      0.98       778
#           SR       0.92      0.93      0.92       445
#
#     accuracy                           0.89      2130
#    macro avg       0.88      0.87      0.87      2130
# weighted avg       0.90      0.89      0.89      2130
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6666 - loss: 0.8384 - val_accuracy: 0.8122 - val_loss: 0.5992
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.8875 - loss: 0.3516 - val_accuracy: 0.7946 - val_loss: 0.6411
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.8974 - loss: 0.3073 - val_accuracy: 0.7735 - val_loss: 0.6217
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8999 - loss: 0.2795 - val_accuracy: 0.7001 - val_loss: 0.7875
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9079 - loss: 0.2897 - val_accuracy: 0.7594 - val_loss: 0.7413
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9162 - loss: 0.2584 - val_accuracy: 0.6925 - val_loss: 0.8618
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9219 - loss: 0.2388 - val_accuracy: 0.6532 - val_loss: 1.1425
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9185 - loss: 0.2433 - val_accuracy: 0.6960 - val_loss: 0.8975
# Epoch 9/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9260 - loss: 0.2332 - val_accuracy: 0.6684 - val_loss: 1.0549
# Epoch 10/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.9215 - loss: 0.2234 - val_accuracy: 0.7201 - val_loss: 0.7840
# Epoch 11/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9229 - loss: 0.2195 - val_accuracy: 0.6479 - val_loss: 1.2242
# Epoch 12/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.
100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.9485 - loss: 0.1495 - val_accuracy: 0.7312 - val_loss: 0.9467
# Epoch 39/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9509 - loss: 0.1497 - val_accuracy: 0.7230 - val_loss: 1.0335
# Epoch 40/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9467 - loss: 0.1457 - val_accuracy: 0.6866 - val_loss: 1.1850
# Epoch 41/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.9476 - loss: 0.1511 - val_accuracy: 0.7083 - val_loss: 1.0470
# Epoch 42/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9437 - loss: 0.1580 - val_accuracy: 0.7083 - val_loss: 1.0624
# Epoch 43/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.9478 - loss: 0.1501 - val_accuracy: 0.6749 - val_loss: 1.3981
# Epoch 44/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9487 - loss: 0.1561 - val_accuracy: 0.6725 - val_loss: 1.3404
# Epoch 45/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9569 - loss: 0.1283 - val_accuracy: 0.6878 - val_loss: 1.1834
# Epoch 46/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9527 - loss: 0.1321 - val_accuracy: 0.7453 - val_loss: 0.9577
# Epoch 47/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9490 - loss: 0.1499 - val_accuracy: 0.7130 - val_loss: 1.0577
# Epoch 48/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9513 - loss: 0.1504 - val_accuracy: 0.6661 - val_loss: 1.4196
# Epoch 49/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9497 - loss: 0.1465 - val_accuracy: 0.6860 - val_loss: 1.2894
# Epoch 50/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9423 - loss: 0.1635 - val_accuracy: 0.7048 - val_loss: 1.2272
# Epoch 51/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9483 - loss: 0.1510 - val_accuracy: 0.6778 - val_loss: 1.3645
# Epoch 52/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9487 - loss: 0.1426 - val_accuracy: 0.7694 - val_loss: 0.8555
# Epoch 53/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9486 - loss: 0.1525 - val_accuracy: 0.6872 - val_loss: 1.2368
# Epoch 54/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9491 - loss: 0.1431 - val_accuracy: 0.7741 - val_loss: 0.8162
# Epoch 55/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9501 - loss: 0.1481 - val_accuracy: 0.6972 - val_loss: 1.1433
# Epoch 56/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.9483 - loss: 0.1421 - val_accuracy: 0.6913 - val_loss: 1.1939
# Epoch 57/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9463 - loss: 0.1523 - val_accuracy: 0.6890 - val_loss: 1.1513
# Epoch 58/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9478 - loss: 0.1446 - val_accuracy: 0.6819 - val_loss: 1.3167
# Epoch 59/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9515 - loss: 0.1436 - val_accuracy: 0.7025 - val_loss: 1.1161
# Epoch 60/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9446 - loss: 0.1420 - val_accuracy: 0.6761 - val_loss: 1.2249
# Epoch 61/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9553 - loss: 0.1333 - val_accuracy: 0.6872 - val_loss: 1.1674
# Epoch 62/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9526 - loss: 0.1281 - val_accuracy: 0.6878 - val_loss: 1.3787
# Epoch 63/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9556 - loss: 0.1313 - val_accuracy: 0.6919 - val_loss: 1.2700
# Epoch 64/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9506 - loss: 0.1383 - val_accuracy: 0.7136 - val_loss: 1.0715
# Epoch 65/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.9565 - loss: 0.1286 - val_accuracy: 0.6825 - val_loss: 1.2294
# Epoch 66/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9447 - loss: 0.1482 - val_accuracy: 0.6878 - val_loss: 1.2108
# Epoch 67/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9545 - loss: 0.1242 - val_accuracy: 0.7465 - val_loss: 0.8956
# Epoch 68/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9509 - loss: 0.1313 - val_accuracy: 0.7072 - val_loss: 1.1223
# Epoch 69/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.9515 - loss: 0.1409 - val_accuracy: 0.6884 - val_loss: 1.1962
# Epoch 70/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.73      0.90      0.81       445
#         GSVT       0.94      0.75      0.83       461
#           SB       0.98      0.97      0.97       778
#           SR       0.94      0.92      0.93       445
#
#     accuracy                           0.90      2129
#    macro avg       0.90      0.89      0.89      2129
# weighted avg       0.91      0.90      0.90      2129
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6083 - loss: 0.9357 - val_accuracy: 0.8339 - val_loss: 0.5628
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.8806 - loss: 0.3459 - val_accuracy: 0.7254 - val_loss: 0.7032
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8974 - loss: 0.3131 - val_accuracy: 0.8028 - val_loss: 0.5732
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9033 - loss: 0.2842 - val_accuracy: 0.8134 - val_loss: 0.5672
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9146 - loss: 0.2518 - val_accuracy: 0.7741 - val_loss: 0.5934
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9183 - loss: 0.2485 - val_accuracy: 0.6808 - val_loss: 0.8883
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.9193 - loss: 0.2411 - val_accuracy: 0.7606 - val_loss: 0.6791
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9192 - loss: 0.2373 - val_accuracy: 0.7089 - val_loss: 0.7394
# Epoch 9/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.9252 - loss: 0.2280 - val_accuracy: 0.7318 - val_loss: 0.6604
# Epoch 10/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.9141 - loss: 0.2238 - val_accuracy: 0.7406 - val_loss: 0.6414
# Epoch 11/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9233 - loss: 0.2066 - val_accuracy: 0.6408 - val_loss: 1.2014
# Epoch 12/100
# ...
# Epoch 91/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.9552 - loss: 0.1183 - val_accuracy: 0.7365 - val_loss: 1.0857
# Epoch 92/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9607 - loss: 0.1123 - val_accuracy: 0.7230 - val_loss: 1.0489
# Epoch 93/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9564 - loss: 0.1133 - val_accuracy: 0.6655 - val_loss: 1.3359
# Epoch 94/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9561 - loss: 0.1185 - val_accuracy: 0.6714 - val_loss: 1.2487
# Epoch 95/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.9558 - loss: 0.1176 - val_accuracy: 0.7248 - val_loss: 1.0398
# Epoch 96/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9565 - loss: 0.1146 - val_accuracy: 0.7359 - val_loss: 1.0218
# Epoch 97/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.9577 - loss: 0.1160 - val_accuracy: 0.7142 - val_loss: 1.1474
# Epoch 98/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9545 - loss: 0.1214 - val_accuracy: 0.6725 - val_loss: 1.4002
# Epoch 99/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9583 - loss: 0.1117 - val_accuracy: 0.7083 - val_loss: 1.2984
# Epoch 100/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.9574 - loss: 0.1137 - val_accuracy: 0.6626 - val_loss: 1.5430
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.71      0.91      0.80       445
#         GSVT       0.90      0.69      0.78       461
#           SB       0.98      0.98      0.98       778
#           SR       0.94      0.91      0.93       445
#
#     accuracy                           0.89      2129
#    macro avg       0.89      0.87      0.87      2129
# weighted avg       0.90      0.89      0.89      2129
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6819 - loss: 0.8109 - val_accuracy: 0.8427 - val_loss: 0.5473
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.8821 - loss: 0.3659 - val_accuracy: 0.7054 - val_loss: 0.8347
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.8911 - loss: 0.3289 - val_accuracy: 0.7130 - val_loss: 0.7717
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9037 - loss: 0.2944 - val_accuracy: 0.6631 - val_loss: 0.9857
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.9191 - loss: 0.2603 - val_accuracy: 0.6696 - val_loss: 0.9302
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.9171 - loss: 0.2491 - val_accuracy: 0.6538 - val_loss: 1.0311
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.9127 - loss: 0.2544 - val_accuracy: 0.6538 - val_loss: 1.0773
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0
100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.9502 - loss: 0.1329 - val_accuracy: 0.6743 - val_loss: 1.3365
# Epoch 73/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9486 - loss: 0.1448 - val_accuracy: 0.6608 - val_loss: 1.6688
# Epoch 74/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9564 - loss: 0.1209 - val_accuracy: 0.6520 - val_loss: 1.7060
# Epoch 75/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.9544 - loss: 0.1319 - val_accuracy: 0.6573 - val_loss: 1.8607
# Epoch 76/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9524 - loss: 0.1363 - val_accuracy: 0.6766 - val_loss: 1.5240
# Epoch 77/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9485 - loss: 0.1392 - val_accuracy: 0.6543 - val_loss: 1.6943
# Epoch 78/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9504 - loss: 0.1366 - val_accuracy: 0.6790 - val_loss: 1.4691
# Epoch 79/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9552 - loss: 0.1248 - val_accuracy: 0.6543 - val_loss: 1.7199
# Epoch 80/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9582 - loss: 0.1309 - val_accuracy: 0.6761 - val_loss: 1.4458
# Epoch 81/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.9554 - loss: 0.1249 - val_accuracy: 0.6819 - val_loss: 1.4399
# Epoch 82/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9569 - loss: 0.1216 - val_accuracy: 0.6702 - val_loss: 1.5804
# Epoch 83/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.9550 - loss: 0.1263 - val_accuracy: 0.6631 - val_loss: 1.7057
# Epoch 84/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.9580 - loss: 0.1160 - val_accuracy: 0.6684 - val_loss: 1.7426
# Epoch 85/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9528 - loss: 0.1313 - val_accuracy: 0.6667 - val_loss: 1.7034
# Epoch 86/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9562 - loss: 0.1224 - val_accuracy: 0.6989 - val_loss: 1.2968
# Epoch 87/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9544 - loss: 0.1386 - val_accuracy: 0.6450 - val_loss: 1.9398
# Epoch 88/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9548 - loss: 0.1292 - val_accuracy: 0.6614 - val_loss: 1.7058
# Epoch 89/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9574 - loss: 0.1175 - val_accuracy: 0.6749 - val_loss: 1.6344
# Epoch 90/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9598 - loss: 0.1118 - val_accuracy: 0.6420 - val_loss: 1.9148
# Epoch 91/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9504 - loss: 0.1301 - val_accuracy: 0.6631 - val_loss: 1.6661
# Epoch 92/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9560 - loss: 0.1249 - val_accuracy: 0.6684 - val_loss: 1.5892
# Epoch 93/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9507 - loss: 0.1248 - val_accuracy: 0.6708 - val_loss: 1.6393
# Epoch 94/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9575 - loss: 0.1154 - val_accuracy: 0.6702 - val_loss: 1.7360
# Epoch 95/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.9553 - loss: 0.1295 - val_accuracy: 0.6673 - val_loss: 1.7212
# Epoch 96/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.9585 - loss: 0.1157 - val_accuracy: 0.6567 - val_loss: 1.8272
# Epoch 97/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9540 - loss: 0.1224 - val_accuracy: 0.6802 - val_loss: 1.5635
# Epoch 98/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.9583 - loss: 0.1128 - val_accuracy: 0.6532 - val_loss: 1.8050
# Epoch 99/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9566 - loss: 0.1207 - val_accuracy: 0.6725 - val_loss: 1.6041
# Epoch 100/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.9574 - loss: 0.1248 - val_accuracy: 0.6479 - val_loss: 1.9152
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.69      0.91      0.79       445
#         GSVT       0.93      0.63      0.75       462
#           SB       0.97      0.98      0.98       777
#           SR       0.93      0.93      0.93       445
#
#     accuracy                           0.88      2129
#    macro avg       0.88      0.86      0.86      2129
# weighted avg       0.90      0.88      0.88      2129
#
#
# Mean Cross-Validation Accuracy: 0.89
