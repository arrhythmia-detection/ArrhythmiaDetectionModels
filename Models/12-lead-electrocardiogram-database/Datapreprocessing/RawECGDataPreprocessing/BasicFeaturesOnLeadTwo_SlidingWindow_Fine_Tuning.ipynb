# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm
import tensorflow as tf
# noinspection PyUnresolvedReferences
from tensorflow.keras.models import Sequential
# noinspection PyUnresolvedReferences
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, BatchNormalization

# Constant seeding
tf.random.set_seed(5950)

# Constants
SAMPLING_RATE = 500  # Hz
WINDOW_SIZE = 2 * SAMPLING_RATE
STEP_SIZE = 1 * SAMPLING_RATE
ecg_folder = "../../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}

# Load diagnostics data
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)
# Out:
# 2024-11-27 11:53:34.600836: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 11:53:34.611933: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 11:53:34.615328: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 11:53:34.624441: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-27 11:53:35.165395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
diagnostics_df
# Out:
#                          FileName Rhythm       Beat  PatientAge  Gender  \
# 0      MUSE_20180113_171327_27000   AFIB   RBBB TWC          85    MALE
# 1      MUSE_20180112_073319_29000     SB        TWC          59  FEMALE
# 2      MUSE_20180111_165520_97000     SR       NONE          20  FEMALE
# 3      MUSE_20180113_121940_44000     SB       NONE          66    MALE
# 4      MUSE_20180112_122850_57000   AFIB  STDD STTC          73  FEMALE
# ...                           ...    ...        ...         ...     ...
# 10641  MUSE_20181222_204306_99000   GSVT       NONE          80  FEMALE
# 10642  MUSE_20181222_204309_22000   GSVT       NONE          81  FEMALE
# 10643  MUSE_20181222_204310_31000   GSVT       NONE          39    MALE
# 10644  MUSE_20181222_204312_58000   GSVT       NONE          76    MALE
# 10645  MUSE_20181222_204314_78000   GSVT       NONE          75    MALE
#
#        VentricularRate  AtrialRate  QRSDuration  QTInterval  QTCorrected  \
# 0                  117         234          114         356          496
# 1                   52          52           92         432          401
# 2                   67          67           82         382          403
# 3                   53          53           96         456          427
# 4                  162         162          114         252          413
# ...                ...         ...          ...         ...          ...
# 10641              196          73          168         284          513
# 10642              162          81          162         294          482
# 10643              152          92          152         340          540
# 10644              175         178          128         310          529
# 10645              117         104          140         312          435
#
#        RAxis  TAxis  QRSCount  QOnset  QOffset  TOffset
# 0         81    -27        19     208      265      386
# 1         76     42         8     215      261      431
# 2         88     20        11     224      265      415
# 3         34      3         9     219      267      447
# 4         68    -40        26     228      285      354
# ...      ...    ...       ...     ...      ...      ...
# 10641    258    244        32     177      261      319
# 10642    110    -75        27     173      254      320
# 10643    250     38        25     208      284      378
# 10644     98    -83        29     205      269      360
# 10645    263    144        19     208      278      364
#
# [10646 rows x 16 columns]

# %%
def preprocess_ecg_data(ecg_folder, diagnostics_df):
    segments = []
    segment_labels = []

    for _, row in tqdm(diagnostics_df.iterrows(), total=diagnostics_df.shape[0]):
        file_name = row['FileName']
        rhythm_label = row['Rhythm']

        # Skip if rhythm label is invalid
        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            print("Invalid rhythm label", rhythm_label)
            continue

        # Load ECG file
        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            print("File not found", ecg_file)
            continue

        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)
        # print(ecg_data.shape)

        # Normalize the signal
        # ecg_data = (ecg_data - np.mean(ecg_data)) / np.std(ecg_data)
        # print(len(ecg_data))
        # Segment the data using sliding window
        for start in range(0, len(ecg_data) - WINDOW_SIZE + 1, STEP_SIZE):
            segment = ecg_data[start:start + WINDOW_SIZE]
            segments.append(segment)
            segment_labels.append(rhythm_label)

    return np.array(segments), np.array(segment_labels)


# Preprocess data
segments, segment_labels = preprocess_ecg_data(ecg_folder, diagnostics_df)
segments
# Out:
# 100%|██████████| 10646/10646 [00:56<00:00, 189.99it/s]
# array([[ 263.52,  263.52,  263.52, ...,    0.  ,  -19.52,  -14.64],
#        [ -68.32,  -58.56,  -53.68, ...,  -53.68,  -53.68,  -78.08],
#        [   0.  ,  -14.64,  -19.52, ...,  112.24,  126.88,  141.52],
#        ...,
#        [ 136.64,  131.76,  136.64, ...,  -14.64,   -4.88,    4.88],
#        [  73.2 ,   68.32,   73.2 , ..., -107.36,  -97.6 ,  -97.6 ],
#        [   4.88,    4.88,    9.76, ..., -214.72, -224.48, -234.24]])

# %%
# Encode labels
label_encoder = LabelEncoder()
segment_labels_encoded = label_encoder.fit_transform(segment_labels)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(segments, segment_labels_encoded, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.29      0.30      0.29      1740
#         GSVT       0.51      0.47      0.49      1868
#           SB       0.66      0.67      0.66      3100
#           SR       0.40      0.39      0.40      1809
#
#     accuracy                           0.49      8517
#    macro avg       0.46      0.46      0.46      8517
# weighted avg       0.49      0.49      0.49      8517
#
# Depth of the tree 98
# Leaf nodes of the tree 5361

# %%
# MLP
mlp = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(len(label_encoder.classes_), activation='softmax')
])

mlp.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mlp.fit(X_train, y_train, epochs=100, batch_size=1024, validation_data=(X_test, y_test))
y_pred_mlp = np.argmax(mlp.predict(X_test), axis=1)
print("MLP Classification Report:")
print(classification_report(y_test, y_pred_mlp, target_names=label_encoder.classes_))
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732686932.751535  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.791939  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.799561  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.806400  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.809565  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.814926  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.923748  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.924850  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732686932.925887  146919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-27 11:55:32.926894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5740 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732686934.292837  149296 service.cc:146] XLA service 0x705ce8002da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732686934.292875  149296 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-11-27 11:55:34.329007: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-27 11:55:34.442135: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-11-27 11:55:35.013468: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1481', 408 bytes spill stores, 440 bytes spill loads
#
# 2024-11-27 11:55:35.022696: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1481', 2852 bytes spill stores, 2760 bytes spill loads
# 21/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2547 - loss: 2.1497
# I0000 00:00:1732686935.985014  149296 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-11-27 11:55:36.539127: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1481', 16 bytes spill stores, 16 bytes spill loads
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.2736 - loss: 2.0485 - val_accuracy: 0.4086 - val_loss: 1.8751
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4123 - loss: 1.4548 - val_accuracy: 0.5530 - val_loss: 1.1695
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4781 - loss: 1.2791 - val_accuracy: 0.6015 - val_loss: 1.0106
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5167 - loss: 1.1629 - val_accuracy: 0.6319 - val_loss: 0.9427
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5467 - loss: 1.1003 - val_accuracy: 0.6541 - val_loss: 0.8887
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5725 - loss: 1.0378 - val_accuracy: 0.6663 - val_loss: 0.8543
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5888 - loss: 0.9933 - val_accuracy: 0.6792 - val_loss: 0.8332
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6095 - loss: 0.9558 - val_accuracy: 0.6864 - val_loss: 0.8167
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6196 - loss: 0.9312 - val_accuracy: 0.6884 - val_loss: 0.8012
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6327 - loss: 0.8980 - val_accuracy: 0.6906 - val_loss: 0.7884
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6448 - loss: 0.8774 - val_accuracy: 0.6952 - val_loss: 0.7752
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6519 - loss: 0.8651 - val_accuracy: 0.6979 - val_loss: 0.7667
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6569 - loss: 0.8492 - val_accuracy: 0.7000 - val_loss: 0.7568
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6600 - loss: 0.8371 - val_accuracy: 0.7032 - val_loss: 0.7460
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6680 - loss: 0.8246 - val_accuracy: 0.7074 - val_loss: 0.7381
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6758 - loss: 0.8053 - val_accuracy: 0.7078 - val_loss: 0.7309
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6788 - loss: 0.7975 - val_accuracy: 0.7083 - val_loss: 0.7248
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6776 - loss: 0.7949 - val_accuracy: 0.7094 - val_loss: 0.7215
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6850 - loss: 0.7784 - val_accuracy: 0.7088 - val_loss: 0.7193
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6845 - loss: 0.7791 - val_accuracy: 0.7128 - val_loss: 0.7116
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6903 - loss: 0.7629 - val_accuracy: 0.7152 - val_loss: 0.7091
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6898 - loss: 0.7586 - val_accuracy: 0.7155 - val_loss: 0.7058
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6878 - loss: 0.7606 - val_accuracy: 0.7163 - val_loss: 0.7033
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7015 - loss: 0.7418 - val_accuracy: 0.7183 - val_loss: 0.6979
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6990 - loss: 0.7387 - val_accuracy: 0.7222 - val_loss: 0.6954
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7028 - loss: 0.7318 - val_accuracy: 0.7211 - val_loss: 0.6943
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7046 - loss: 0.7300 - val_accuracy: 0.7214 - val_loss: 0.6925
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7013 - loss: 0.7320 - val_accuracy: 0.7236 - val_loss: 0.6894
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7063 - loss: 0.7274 - val_accuracy: 0.7235 - val_loss: 0.6888
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7091 - loss: 0.7163 - val_accuracy: 0.7244 - val_loss: 0.6850
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7057 - loss: 0.7243 - val_accuracy: 0.7243 - val_loss: 0.6843
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7106 - loss: 0.7226 - val_accuracy: 0.7284 - val_loss: 0.6823
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7116 - loss: 0.7126 - val_accuracy: 0.7287 - val_loss: 0.6815
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7156 - loss: 0.7082 - val_accuracy: 0.7304 - val_loss: 0.6782
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7135 - loss: 0.7079 - val_accuracy: 0.7336 - val_loss: 0.6741
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7138 - loss: 0.7048 - val_accuracy: 0.7323 - val_loss: 0.6725
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7194 - loss: 0.6978 - val_accuracy: 0.7305 - val_loss: 0.6735
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7221 - loss: 0.6980 - val_accuracy: 0.7332 - val_loss: 0.6712
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7250 - loss: 0.6937 - val_accuracy: 0.7359 - val_loss: 0.6732
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7194 - loss: 0.7012 - val_accuracy: 0.7318 - val_loss: 0.6726
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7200 - loss: 0.6913 - val_accuracy: 0.7307 - val_loss: 0.6703
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7213 - loss: 0.6852 - val_accuracy: 0.7324 - val_loss: 0.6717
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7228 - loss: 0.6837 - val_accuracy: 0.7314 - val_loss: 0.6694
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7243 - loss: 0.6788 - val_accuracy: 0.7308 - val_loss: 0.6684
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7279 - loss: 0.6774 - val_accuracy: 0.7372 - val_loss: 0.6647
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7294 - loss: 0.6716 - val_accuracy: 0.7372 - val_loss: 0.6636
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7256 - loss: 0.6854 - val_accuracy: 0.7349 - val_loss: 0.6665
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7260 - loss: 0.6852 - val_accuracy: 0.7356 - val_loss: 0.6652
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7318 - loss: 0.6657 - val_accuracy: 0.7339 - val_loss: 0.6659
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7369 - loss: 0.6679 - val_accuracy: 0.7366 - val_loss: 0.6640
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7303 - loss: 0.6764 - val_accuracy: 0.7397 - val_loss: 0.6600
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 0.6711 - val_accuracy: 0.7361 - val_loss: 0.6608
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.6591 - val_accuracy: 0.7382 - val_loss: 0.6585
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7322 - loss: 0.6633 - val_accuracy: 0.7362 - val_loss: 0.6604
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7377 - loss: 0.6591 - val_accuracy: 0.7390 - val_loss: 0.6585
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7369 - loss: 0.6512 - val_accuracy: 0.7382 - val_loss: 0.6564
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - loss: 0.6578 - val_accuracy: 0.7373 - val_loss: 0.6576
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7388 - loss: 0.6573 - val_accuracy: 0.7365 - val_loss: 0.6572
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7402 - loss: 0.6538 - val_accuracy: 0.7357 - val_loss: 0.6564
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7382 - loss: 0.6507 - val_accuracy: 0.7403 - val_loss: 0.6538
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7424 - loss: 0.6404 - val_accuracy: 0.7415 - val_loss: 0.6540
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7428 - loss: 0.6508 - val_accuracy: 0.7386 - val_loss: 0.6545
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7368 - loss: 0.6547 - val_accuracy: 0.7408 - val_loss: 0.6537
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7411 - loss: 0.6497 - val_accuracy: 0.7391 - val_loss: 0.6538
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7457 - loss: 0.6410 - val_accuracy: 0.7405 - val_loss: 0.6536
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7439 - loss: 0.6447 - val_accuracy: 0.7408 - val_loss: 0.6522
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.6511 - val_accuracy: 0.7403 - val_loss: 0.6533
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7456 - loss: 0.6451 - val_accuracy: 0.7411 - val_loss: 0.6497
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7498 - loss: 0.6369 - val_accuracy: 0.7427 - val_loss: 0.6489
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7469 - loss: 0.6317 - val_accuracy: 0.7386 - val_loss: 0.6531
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7496 - loss: 0.6315 - val_accuracy: 0.7423 - val_loss: 0.6482
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7500 - loss: 0.6321 - val_accuracy: 0.7430 - val_loss: 0.6497
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7497 - loss: 0.6389 - val_accuracy: 0.7432 - val_loss: 0.6489
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7504 - loss: 0.6325 - val_accuracy: 0.7445 - val_loss: 0.6478
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7423 - loss: 0.6488 - val_accuracy: 0.7391 - val_loss: 0.6520
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7511 - loss: 0.6284 - val_accuracy: 0.7397 - val_loss: 0.6479
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7480 - loss: 0.6354 - val_accuracy: 0.7398 - val_loss: 0.6489
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7525 - loss: 0.6226 - val_accuracy: 0.7384 - val_loss: 0.6482
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7520 - loss: 0.6241 - val_accuracy: 0.7386 - val_loss: 0.6479
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7531 - loss: 0.6268 - val_accuracy: 0.7403 - val_loss: 0.6487
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7512 - loss: 0.6265 - val_accuracy: 0.7386 - val_loss: 0.6483
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7569 - loss: 0.6195 - val_accuracy: 0.7437 - val_loss: 0.6464
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7563 - loss: 0.6190 - val_accuracy: 0.7429 - val_loss: 0.6438
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7554 - loss: 0.6180 - val_accuracy: 0.7431 - val_loss: 0.6444
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7529 - loss: 0.6189 - val_accuracy: 0.7400 - val_loss: 0.6489
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7554 - loss: 0.6210 - val_accuracy: 0.7425 - val_loss: 0.6443
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7526 - loss: 0.6217 - val_accuracy: 0.7451 - val_loss: 0.6419
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 0.6150 - val_accuracy: 0.7473 - val_loss: 0.6400
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7549 - loss: 0.6233 - val_accuracy: 0.7458 - val_loss: 0.6429
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7503 - loss: 0.6256 - val_accuracy: 0.7439 - val_loss: 0.6412
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7619 - loss: 0.6109 - val_accuracy: 0.7416 - val_loss: 0.6423
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7550 - loss: 0.6189 - val_accuracy: 0.7429 - val_loss: 0.6439
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7542 - loss: 0.6197 - val_accuracy: 0.7452 - val_loss: 0.6407
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7602 - loss: 0.6064 - val_accuracy: 0.7438 - val_loss: 0.6398
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 0.6132 - val_accuracy: 0.7406 - val_loss: 0.6426
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7582 - loss: 0.6196 - val_accuracy: 0.7424 - val_loss: 0.6442
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7586 - loss: 0.6143 - val_accuracy: 0.7399 - val_loss: 0.6404
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7631 - loss: 0.6099 - val_accuracy: 0.7397 - val_loss: 0.6427
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7561 - loss: 0.6094 - val_accuracy: 0.7427 - val_loss: 0.6393
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7583 - loss: 0.6039 - val_accuracy: 0.7480 - val_loss: 0.6366
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MLP Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.50      0.61      0.55      1740
#         GSVT       0.80      0.67      0.73      1868
#           SB       0.89      0.90      0.90      3100
#           SR       0.75      0.69      0.72      1809
#
#     accuracy                           0.75      8517
#    macro avg       0.73      0.72      0.72      8517
# weighted avg       0.76      0.75      0.75      8517

# %%
# Decision Tree
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train.reshape(X_train.shape[0], -1), y_train)
y_pred_dt = dt.predict(X_test.reshape(X_test.shape[0], -1))
print("Decision Tree Classification Report:")
print(classification_report(y_test, y_pred_dt, target_names=label_encoder.classes_))
print("Depth of the tree", dt.get_depth())
print("Leaf nodes of the tree", dt.get_n_leaves())
