# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report
import logging

# Set up logging
logging.basicConfig(filename='ecg_processing.log', level=logging.INFO,
                   format='%(asctime)s:%(levelname)s:%(message)s')

# Constants
SAMPLING_RATE = 500  # Hz
SEQUENCE_LENGTH = 5000  # 10 seconds * 500 Hz
N_LEADS = 12


ecg_folder = "../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Rhythm Mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}

# %%
def load_and_preprocess_data(ecg_folder, diagnostics_file, rhythm_mapping):
    """Load and preprocess ECG data and labels."""
    # Load diagnostics data
    diagnostics = pd.read_excel(diagnostics_file)

    # Map rhythms to reduced set of labels
    diagnostics['Rhythm'] = diagnostics['Rhythm'].map(rhythm_mapping)

    valid_files = []
    valid_data = []
    valid_labels = []

    # Process each ECG file
    for idx, row in diagnostics.iterrows():
        file_path = os.path.join(ecg_folder, row['FileName'] + ".csv")

        try:
            # Load ECG data
            ecg_data = pd.read_csv(file_path, header=0)

            # Check for missing or zero values
            if ecg_data.isnull().any().any() or (ecg_data == 0).all().any():
                logging.warning(f"File {row['FileName']} contains null or all-zero leads - skipped")
                continue

            # Check if data has expected length
            if len(ecg_data) != SEQUENCE_LENGTH:
                logging.warning(f"File {row['FileName']} has unexpected length {len(ecg_data)} - skipped")
                continue

            # Store valid data
            valid_files.append(row['FileName'])
            valid_data.append(ecg_data.values)
            valid_labels.append(row['Rhythm'])

        except Exception as e:
            logging.error(f"Error processing {row['FileName']}: {str(e)}")
            continue

    # Convert to numpy arrays
    X = np.array(valid_data)
    y = np.array(valid_labels)

    return X, y, valid_files

def prepare_data(X, y, use_single_lead=False):
    """Prepare data for training - normalize and split."""
    # Reshape data if using single lead
    if use_single_lead:
        X = X[:, :, 1:2]  # Keep only second lead

    # Reshape for preprocessing
    original_shape = X.shape
    X_reshaped = X.reshape(-1, X.shape[-1])

    # Normalize using z-score
    scaler = StandardScaler()
    X_normalized = scaler.fit_transform(X_reshaped)
    X = X_normalized.reshape(original_shape)

    # Convert string labels to integer indices
    label_encoder = tf.keras.preprocessing.text.Tokenizer()
    label_encoder.fit_on_texts(y)
    y_encoded = label_encoder.texts_to_sequences(y)
    y_encoded = np.array(y_encoded).reshape(-1)

    # Convert to one-hot encoding
    num_classes = len(label_encoder.word_index)
    y_onehot = tf.keras.utils.to_categorical(y_encoded - 1, num_classes)  # Subtract 1 since word_index starts from 1

    # Get class names in order
    classes = [k for k, v in sorted(label_encoder.word_index.items(), key=lambda x: x[1])]

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(
        X, y_onehot, test_size=0.2, random_state=42, stratify=y_onehot
    )

    return X_train, X_test, y_train, y_test, classes

def create_mlp_model(input_shape, num_classes):
    """Create MLP model."""
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=input_shape),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

def create_cnn_model(input_shape, num_classes):
    """Create CNN model."""
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(32, 5, activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, 5, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, 5, activation='relu'),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

def train_and_evaluate(model, X_train, X_test, y_train, y_test, classes, model_name):
    """Train model and print evaluation metrics."""
    # Compile model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train model
    history = model.fit(
        X_train, y_train,
        epochs=20,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    # Print classification report
    print(f"\nClassification Report for {model_name}:")
    print(classification_report(y_test_classes, y_pred_classes,
                                target_names=classes, digits=5))

    return history

# Load and preprocess data
X, y, valid_files = load_and_preprocess_data(ecg_folder, diagnostics_file, rhythm_mapping)
logging.info(f"Successfully processed {len(valid_files)} files")

# Train and evaluate models using all leads
print("\nTraining models with all leads:")
X_train, X_test, y_train, y_test, classes = prepare_data(X, y, use_single_lead=False)

# Train MLP
mlp_model = create_mlp_model((SEQUENCE_LENGTH, N_LEADS), len(classes))
mlp_history = train_and_evaluate(mlp_model, X_train, X_test, y_train, y_test,
                                 classes, "MLP (All Leads)")

# Train CNN
cnn_model = create_cnn_model((SEQUENCE_LENGTH, N_LEADS), len(classes))
cnn_history = train_and_evaluate(cnn_model, X_train, X_test, y_train, y_test,
                                 classes, "CNN (All Leads)")

# Train and evaluate models using single lead
print("\nTraining models with single lead:")
X_train, X_test, y_train, y_test, classes = prepare_data(X, y, use_single_lead=True)

# Train MLP
mlp_model_single = create_mlp_model((SEQUENCE_LENGTH, 1), len(classes))
mlp_history_single = train_and_evaluate(mlp_model_single, X_train, X_test,
                                        y_train, y_test, classes, "MLP (Single Lead)")

# Train CNN
cnn_model_single = create_cnn_model((SEQUENCE_LENGTH, 1), len(classes))
cnn_history_single = train_and_evaluate(cnn_model_single, X_train, X_test,
                                        y_train, y_test, classes, "CNN (Single Lead)")
# Out:
# Training models with all leads:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735164332.812718  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164332.949153  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164332.953200  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164332.957563  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164332.960126  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164332.962531  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164333.077571  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164333.078707  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1735164333.079760  132452 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-26 04:05:33.080770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5363 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# 2024-12-26 04:05:33.628213: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1632480000 exceeds 10% of free system memory.
# 2024-12-26 04:05:35.027847: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1632480000 exceeds 10% of free system memory.
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735164336.332438  133997 service.cc:146] XLA service 0x77c290005a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1735164336.332474  133997 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-12-26 04:05:36.369173: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-26 04:05:36.484487: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#  49/213 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3223 - loss: 7.0677
# I0000 00:00:1735164337.481436  133997 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.3791 - loss: 6.2313 - val_accuracy: 0.5026 - val_loss: 1.3597
# Epoch 2/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5909 - loss: 1.3674 - val_accuracy: 0.5150 - val_loss: 1.0982
# Epoch 3/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6760 - loss: 0.9010 - val_accuracy: 0.5514 - val_loss: 1.0322
# Epoch 4/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7099 - loss: 0.7855 - val_accuracy: 0.5708 - val_loss: 1.0261
# Epoch 5/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7704 - loss: 0.6254 - val_accuracy: 0.5661 - val_loss: 1.0296
# Epoch 6/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7812 - loss: 0.6106 - val_accuracy: 0.5826 - val_loss: 1.0423
# Epoch 7/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8081 - loss: 0.5278 - val_accuracy: 0.5691 - val_loss: 1.0164
# Epoch 8/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8260 - loss: 0.4942 - val_accuracy: 0.5973 - val_loss: 1.0124
# Epoch 9/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8184 - loss: 0.5012 - val_accuracy: 0.5967 - val_loss: 1.0089
# Epoch 10/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8583 - loss: 0.4222 - val_accuracy: 0.6008 - val_loss: 1.0173
# Epoch 11/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8692 - loss: 0.3892 - val_accuracy: 0.5855 - val_loss: 1.0920
# Epoch 12/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8616 - loss: 0.4098 - val_accuracy: 0.5844 - val_loss: 1.1170
# Epoch 13/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8837 - loss: 0.3720 - val_accuracy: 0.5920 - val_loss: 1.0969
# Epoch 14/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8766 - loss: 0.3744 - val_accuracy: 0.5967 - val_loss: 1.1117
# Epoch 15/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8839 - loss: 0.3819 - val_accuracy: 0.5920 - val_loss: 1.1082
# Epoch 16/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8829 - loss: 0.3495 - val_accuracy: 0.5926 - val_loss: 1.1140
# Epoch 17/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8919 - loss: 0.3301 - val_accuracy: 0.5985 - val_loss: 1.1482
# Epoch 18/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8941 - loss: 0.3444 - val_accuracy: 0.5961 - val_loss: 1.1373
# Epoch 19/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9025 - loss: 0.2854 - val_accuracy: 0.5996 - val_loss: 1.1752
# Epoch 20/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9003 - loss: 0.3007 - val_accuracy: 0.5961 - val_loss: 1.1514
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Classification Report for MLP (All Leads):
#               precision    recall  f1-score   support
#
#           sb    0.87402   0.85604   0.86494       778
#         gsvt    0.62257   0.34783   0.44630       460
#           sr    0.40052   0.69820   0.50903       444
#         afib    0.36637   0.27477   0.31403       444
#
#     accuracy                        0.59172      2126
#    macro avg    0.56587   0.54421   0.53357      2126
# weighted avg    0.61470   0.59172   0.58498      2126
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-26 04:06:01.772833: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1632480000 exceeds 10% of free system memory.
# 2024-12-26 04:06:03.180653: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1632480000 exceeds 10% of free system memory.
# Epoch 1/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.4364 - loss: 1.2809 - val_accuracy: 0.6326 - val_loss: 0.8985
# Epoch 2/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6268 - loss: 0.9075 - val_accuracy: 0.6267 - val_loss: 0.8764
# Epoch 3/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6710 - loss: 0.8061 - val_accuracy: 0.7002 - val_loss: 0.7656
# Epoch 4/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6889 - loss: 0.7664 - val_accuracy: 0.7255 - val_loss: 0.6978
# Epoch 5/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7240 - loss: 0.6915 - val_accuracy: 0.7343 - val_loss: 0.6810
# Epoch 6/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7281 - loss: 0.6790 - val_accuracy: 0.7372 - val_loss: 0.6615
# Epoch 7/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7423 - loss: 0.6621 - val_accuracy: 0.7225 - val_loss: 0.6918
# Epoch 8/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7512 - loss: 0.6227 - val_accuracy: 0.7131 - val_loss: 0.6876
# Epoch 9/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7644 - loss: 0.6168 - val_accuracy: 0.7507 - val_loss: 0.6309
# Epoch 10/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7715 - loss: 0.5809 - val_accuracy: 0.7919 - val_loss: 0.5499
# Epoch 11/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7910 - loss: 0.5534 - val_accuracy: 0.7907 - val_loss: 0.5455
# Epoch 12/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7884 - loss: 0.5480 - val_accuracy: 0.7854 - val_loss: 0.5507
# Epoch 13/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8006 - loss: 0.5256 - val_accuracy: 0.7937 - val_loss: 0.5301
# Epoch 14/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7985 - loss: 0.5196 - val_accuracy: 0.7707 - val_loss: 0.5626
# Epoch 15/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8172 - loss: 0.4848 - val_accuracy: 0.8013 - val_loss: 0.5204
# Epoch 16/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8129 - loss: 0.5027 - val_accuracy: 0.8095 - val_loss: 0.4958
# Epoch 17/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8331 - loss: 0.4461 - val_accuracy: 0.8201 - val_loss: 0.4732
# Epoch 18/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8383 - loss: 0.4294 - val_accuracy: 0.8330 - val_loss: 0.4561
# Epoch 19/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8394 - loss: 0.4398 - val_accuracy: 0.8266 - val_loss: 0.4638
# Epoch 20/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8394 - loss: 0.4302 - val_accuracy: 0.8277 - val_loss: 0.4649
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Classification Report for CNN (All Leads):
#               precision    recall  f1-score   support
#
#           sb    0.85236   0.94987   0.89848       778
#         gsvt    0.82393   0.79348   0.80842       460
#           sr    0.78781   0.78604   0.78692       444
#         afib    0.80965   0.68018   0.73929       444
#
#     accuracy                        0.82549      2126
#    macro avg    0.81844   0.80239   0.80828      2126
# weighted avg    0.82381   0.82549   0.82245      2126
#
#
# Training models with single lead:
# Epoch 1/20
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3757 - loss: 1.7221 - val_accuracy: 0.5362 - val_loss: 1.0768
# Epoch 2/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6033 - loss: 0.9958 - val_accuracy: 0.5614 - val_loss: 1.0333
# Epoch 3/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6905 - loss: 0.7992 - val_accuracy: 0.5697 - val_loss: 1.0273
# Epoch 4/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7325 - loss: 0.6993 - val_accuracy: 0.5885 - val_loss: 1.0721
# Epoch 5/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7633 - loss: 0.6386 - val_accuracy: 0.5791 - val_loss: 1.0366
# Epoch 6/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.5598 - val_accuracy: 0.5791 - val_loss: 1.0698
# Epoch 7/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.5402 - val_accuracy: 0.5914 - val_loss: 1.0655
# Epoch 8/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8143 - loss: 0.5120 - val_accuracy: 0.5926 - val_loss: 1.1469
# Epoch 9/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8538 - loss: 0.4087 - val_accuracy: 0.5920 - val_loss: 1.1463
# Epoch 10/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.4483 - val_accuracy: 0.5955 - val_loss: 1.1704
# Epoch 11/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8597 - loss: 0.4064 - val_accuracy: 0.5938 - val_loss: 1.2506
# Epoch 12/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8608 - loss: 0.4151 - val_accuracy: 0.5991 - val_loss: 1.2311
# Epoch 13/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8703 - loss: 0.3692 - val_accuracy: 0.6002 - val_loss: 1.2803
# Epoch 14/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.3570 - val_accuracy: 0.5996 - val_loss: 1.2751
# Epoch 15/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8867 - loss: 0.3315 - val_accuracy: 0.6114 - val_loss: 1.2696
# Epoch 16/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8988 - loss: 0.3159 - val_accuracy: 0.6026 - val_loss: 1.3512
# Epoch 17/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9032 - loss: 0.2935 - val_accuracy: 0.5949 - val_loss: 1.3013
# Epoch 18/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.3030 - val_accuracy: 0.6079 - val_loss: 1.3652
# Epoch 19/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9000 - loss: 0.2975 - val_accuracy: 0.6079 - val_loss: 1.4150
# Epoch 20/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2592 - val_accuracy: 0.5996 - val_loss: 1.4575
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report for MLP (Single Lead):
#               precision    recall  f1-score   support
#
#           sb    0.83959   0.83419   0.83688       778
#         gsvt    0.58435   0.51957   0.55006       460
#           sr    0.54214   0.53604   0.53907       444
#         afib    0.37228   0.42342   0.39621       444
#
#     accuracy                        0.61806      2126
#    macro avg    0.58459   0.57830   0.58055      2126
# weighted avg    0.62465   0.61806   0.62059      2126
#
# Epoch 1/20
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.4054 - loss: 1.3159 - val_accuracy: 0.5391 - val_loss: 1.0765
# Epoch 2/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5443 - loss: 1.0671 - val_accuracy: 0.5691 - val_loss: 0.9968
# Epoch 3/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5704 - loss: 1.0030 - val_accuracy: 0.5197 - val_loss: 1.1117
# Epoch 4/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6145 - loss: 0.9440 - val_accuracy: 0.5938 - val_loss: 0.9373
# Epoch 5/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6388 - loss: 0.8898 - val_accuracy: 0.6520 - val_loss: 0.8575
# Epoch 6/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6624 - loss: 0.8288 - val_accuracy: 0.6631 - val_loss: 0.8277
# Epoch 7/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6882 - loss: 0.7939 - val_accuracy: 0.7066 - val_loss: 0.7578
# Epoch 8/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7089 - loss: 0.7427 - val_accuracy: 0.6955 - val_loss: 0.7695
# Epoch 9/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6976 - loss: 0.7703 - val_accuracy: 0.7160 - val_loss: 0.7245
# Epoch 10/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7099 - loss: 0.7437 - val_accuracy: 0.7149 - val_loss: 0.7242
# Epoch 11/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7204 - loss: 0.6989 - val_accuracy: 0.6702 - val_loss: 0.7820
# Epoch 12/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7269 - loss: 0.6956 - val_accuracy: 0.7290 - val_loss: 0.6851
# Epoch 13/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7249 - loss: 0.7033 - val_accuracy: 0.7255 - val_loss: 0.6778
# Epoch 14/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7453 - loss: 0.6567 - val_accuracy: 0.7478 - val_loss: 0.6408
# Epoch 15/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7446 - loss: 0.6492 - val_accuracy: 0.7625 - val_loss: 0.6167
# Epoch 16/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7547 - loss: 0.6313 - val_accuracy: 0.7496 - val_loss: 0.6200
# Epoch 17/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7592 - loss: 0.6174 - val_accuracy: 0.7713 - val_loss: 0.6006
# Epoch 18/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7676 - loss: 0.6122 - val_accuracy: 0.7748 - val_loss: 0.5829
# Epoch 19/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7680 - loss: 0.6040 - val_accuracy: 0.7719 - val_loss: 0.5853
# Epoch 20/20
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7721 - loss: 0.5898 - val_accuracy: 0.7878 - val_loss: 0.5607
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Classification Report for CNN (Single Lead):
#               precision    recall  f1-score   support
#
#           sb    0.84892   0.91003   0.87841       778
#         gsvt    0.76152   0.82609   0.79249       460
#           sr    0.73973   0.72973   0.73469       444
#         afib    0.72394   0.57883   0.64330       444
#
#     accuracy                        0.78504      2126
#    macro avg    0.76853   0.76117   0.76223      2126
# weighted avg    0.78111   0.78504   0.78071      2126
