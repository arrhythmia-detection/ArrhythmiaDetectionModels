# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Randomly seeding
tf.random.set_seed(6950)

# Biosppy for signal processing
from biosppy.signals import ecg

# Constants
SAMPLING_RATE = 500  # Hz
ecg_folder = "../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}


# Feature extraction function
def extract_comprehensive_features(ecg_signal):
    """
    Extract comprehensive features from entire ECG signal
    """
    try:
        ecg_processed = ecg.ecg(signal=ecg_signal, sampling_rate=SAMPLING_RATE, show=False)
        rpeaks = ecg_processed['rpeaks']
        heart_rate = ecg_processed['heart_rate']

        features = [
            np.mean(ecg_signal),
            np.std(ecg_signal),
            np.median(ecg_signal),
            np.min(ecg_signal),
            np.max(ecg_signal),
            len(rpeaks),
            np.mean(heart_rate) if len(heart_rate) > 0 else 0,
            np.std(heart_rate) if len(heart_rate) > 0 else 0,
            np.mean(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.std(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.percentile(ecg_signal, 25),
            np.percentile(ecg_signal, 75),
        ]

        return features

    except Exception as e:
        print(f"Error processing signal: {e}")
        return [0] * 12


# Dataset preparation function
def prepare_dataset(ecg_folder, diagnostics_df):
    signals, signal_features, signal_labels = [], [], []

    for _, row in diagnostics_df.iterrows():
        file_name = row['FileName']
        rhythm_label = row['Rhythm']

        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            continue

        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            continue

        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)

        features = extract_comprehensive_features(ecg_data)
        signals.append(ecg_data)
        signal_features.append(features)
        signal_labels.append(rhythm_label)

    return np.array(signals), np.array(signal_features), np.array(signal_labels)


# Load and process data
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)

raw_signals, signal_features, signal_labels = prepare_dataset(ecg_folder, diagnostics_df)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(signal_labels)
onehot_labels = to_categorical(encoded_labels)

feature_scaler = StandardScaler()
scaled_features = feature_scaler.fit_transform(signal_features)


# Create MLP model
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model


# Stratified K-Fold Cross-Validation with optimizer tuning
optimizers = ['adam', 'sgd', 'rmsprop', 'adagrad']
results = {}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for optimizer in optimizers:
    print(f"\nTesting optimizer: {optimizer}")
    cv_scores = []

    for train_index, test_index in skf.split(scaled_features, encoded_labels):
        X_train, X_test = scaled_features[train_index], scaled_features[test_index]
        y_train, y_test = onehot_labels[train_index], onehot_labels[test_index]

        model = create_mlp_model(input_shape=X_train.shape[1], num_classes=onehot_labels.shape[1])
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_split=0.2, verbose=1)
        _, accuracy = model.evaluate(X_test, y_test, verbose=0)
        cv_scores.append(accuracy)

        y_pred = model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_test_classes = np.argmax(y_test, axis=1)

        print("\nClassification Report:")
        print(classification_report(y_test_classes, y_pred_classes, target_names=label_encoder.classes_))

    results[optimizer] = np.mean(cv_scores)
    print(f"Optimizer: {optimizer} - Mean CV Accuracy: {np.mean(cv_scores)}")

print("\nFinal Results:")
for opt, acc in results.items():
    print(f"{opt}: {acc}")
# Out:
# 2024-11-29 09:18:58.928056: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 09:18:58.938969: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 09:18:58.942516: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 09:18:58.951644: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-29 09:18:59.483678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Testing optimizer: adam
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732850624.156794  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.189516  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.192780  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.196428  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.199488  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS ha
# Epoch 1/100
# d negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.202110  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.303141  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.304300  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732850624.305353  543763 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-29 09:23:44.306369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5546 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732850624.997354  546546 service.cc:146] XLA service 0x7ec9e800c160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732850624.997385  546546 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-11-29 09:23:45.016268: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-29 09:23:45.112152: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#  92/107 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5878 - loss: 1.0289
# I0000 00:00:1732850626.243088  546546 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.6085 - loss: 0.9867 - val_accuracy: 0.8310 - val_loss: 0.5598
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8543 - loss: 0.4301 - val_accuracy: 0.8016 - val_loss: 0.6166
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8863 - loss: 0.3562 - val_accuracy: 0.7289 - val_loss: 0.7189
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.8929 - loss: 0.3207 - val_accuracy: 0.7119 - val_loss: 0.7414
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9066 - loss: 0.2857 - val_accuracy: 0.6766 - val_loss: 0.8658
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9055 - loss: 0.2736 - val_accuracy: 0.6678 - val_loss: 0.8890
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9117 - loss: 0.2636 - val_accuracy: 0.6849 - val_loss: 0.8504
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9109 - loss: 0.2642 - val_accuracy: 0.6590 - val_loss: 0.9222
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.9157 - loss: 0.2495 - val_accuracy: 0.6626 - val_loss: 0.8959
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9136 - loss: 0.2418 - val_accuracy: 0.6508 - val_loss: 0.9358
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.9164 - loss: 0.2358 - val_accuracy: 0.6561 - val_loss: 0.9577
# Epoch 12/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.9248 - loss: 0.2304 - val_accuracy: 0.6585 - val_loss: 0.9473
# Epoch 13/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9197 - loss: 0.2276 - val_accuracy: 0.6420 - val_loss: 1.0438
# Epoch 14/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9242 - loss: 0.2244 - val_accuracy: 0.6590 - val_loss: 0.9899
# Epoch 15/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.9240 - loss: 0.2216 - val_accuracy: 0.6590 - val_loss: 1.0091
# Epoch 16/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9233 - loss: 0.2168 - val_accuracy: 0.6426 - val_loss: 1.0898
# Epoch 17/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9246 - loss: 0.2125 - val_accuracy: 0.6667 - val_loss: 1.0127
# Epoch 18/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9253 - loss: 0.2100 - val_accuracy: 0.6485 - val_loss: 1.1243
# Epoch 19/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9278 - loss: 0.2132 - val_accuracy: 0.6602 - val_loss: 1.0069
# Epoch 20/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9260 - loss: 0.2051 - val_accuracy: 0.6473 - val_loss: 1.1111
# Epoch 21/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9279 - loss: 0.2033 - val_accuracy: 0.6714 - val_loss: 0.9845
# Epoch 22/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.9314 - loss: 0.2021 - val_accuracy: 0.6391 - val_loss: 1.2073
# Epoch 23/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9275 - loss: 0.2004 - val_accuracy: 0.6532 - val_loss: 1.0595
# Epoch 24/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9331 - loss: 0.1959 - val_accuracy: 0.6461 - val_loss: 1.0791
# Epoch 25/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9318 - loss: 0.1966 - val_accuracy: 0.6579 - val_loss: 1.1046
# Epoch 26/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9321 - loss: 0.1921 - val_accuracy: 0.6502 - val_loss: 1.0892
# Epoch 27/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9345 - loss: 0.1988 - val_accuracy: 0.6538 - val_loss: 1.1142
# Epoch 28/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.9319 - loss: 0.1891 - val_accuracy: 0.6426 - val_loss: 1.2362
# Epoch 29/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9311 - loss: 0.1905 - val_accuracy: 0.6514 - val_loss: 1.1674
# Epoch 30/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9316 - loss: 0.1935 - val_accuracy: 0.6485 - val_loss: 1.1712
# Epoch 31/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.9331 - loss: 0.1933 - val_accuracy: 0.6543 - val_loss: 1.1311
# Epoch 32/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9351 - loss: 0.1875 - val_accuracy: 0.6526 - val_loss: 1.1807
# Epoch 33/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9345 - loss: 0.1870 - val_accuracy: 0.6532 - val_loss: 1.1400
# Epoch 34/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9359 - loss: 0.1860 - val_accuracy: 0.6508 - val_loss: 1.1940
# Epoch 35/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9377 - loss: 0.1782 - val_accuracy: 0.6538 - val_loss: 1.0940
# Epoch 36/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9391 - loss: 0.1875 - val_accuracy: 0.6590 - val_loss: 1.0928
# Epoch 37/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9339 - loss: 0.1855 - val_accuracy: 0.6379 - val_loss: 1.2069
# Epoch 38/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9356 - loss: 0.1785 - val_accuracy: 0.6502 - val_loss: 1.1517
# Epoch 39/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9370 - loss: 0.1748 - val_accuracy: 0.6608 - val_loss: 1.1451
# Epoch 40/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9330 - loss: 0.1844 - val_accuracy: 0.6520 - val_loss: 1.2784
# Epoch 41/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9344 - loss: 0.1775 - val_accuracy: 0.6444 - val_loss: 1.3527
# Epoch 42/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9358 - loss: 0.1810 - val_accuracy: 0.6631 - val_loss: 1.1878
# Epoch 43/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9395 - loss: 0.1706 - val_accuracy: 0.6626 - val_loss: 1.1972
# Epoch 44/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9320 - loss: 0.1767 - val_accuracy: 0.6491 - val_loss: 1.2466
# Epoch 45/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9385 - loss: 0.1754 - val_accuracy: 0.6514 - val_loss: 1.2583
# Epoch 46/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9370 - loss: 0.1743 - val_accuracy: 0.6496 - val_loss: 1.3570
# Epoch 47/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9380 - loss: 0.1769 - val_accuracy: 0.6719 - val_loss: 1.1915
# Epoch 48/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9418 - loss: 0.1575 - val_accuracy: 0.6538 - val_loss: 1.5460
# Epoch 80/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9372 - loss: 0.1583 - val_accuracy: 0.6444 - val_loss: 1.4803
# Epoch 81/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9425 - loss: 0.1595 - val_accuracy: 0.6514 - val_loss: 1.5093
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9466 - loss: 0.1562 - val_accuracy: 0.6491 - val_loss: 1.5289
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9469 - loss: 0.1543 - val_accuracy: 0.6590 - val_loss: 1.4420
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9471 - loss: 0.1527 - val_accuracy: 0.6561 - val_loss: 1.4226
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9464 - loss: 0.1522 - val_accuracy: 0.6526 - val_loss: 1.4710
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9450 - loss: 0.1538 - val_accuracy: 0.6502 - val_loss: 1.6218
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9427 - loss: 0.1532 - val_accuracy: 0.6626 - val_loss: 1.4375
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9441 - loss: 0.1554 - val_accuracy: 0.6508 - val_loss: 1.6069
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9433 - loss: 0.1530 - val_accuracy: 0.6690 - val_loss: 1.4379
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9437 - loss: 0.1500 - val_accuracy: 0.6673 - val_loss: 1.4134
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9469 - loss: 0.1493 - val_accuracy: 0.6643 - val_loss: 1.4761
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9408 - loss: 0.1603 - val_accuracy: 0.6461 - val_loss: 1.6093
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9508 - loss: 0.1442 - val_accuracy: 0.6520 - val_loss: 1.5810
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9461 - loss: 0.1532 - val_accuracy: 0.6549 - val_loss: 1.5600
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9475 - loss: 0.1476 - val_accuracy: 0.6655 - val_loss: 1.5197
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9509 - loss: 0.1421 - val_accuracy: 0.6555 - val_loss: 1.6181
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9467 - loss: 0.1508 - val_accuracy: 0.6502 - val_loss: 1.5384
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9442 - loss: 0.1463 - val_accuracy: 0.6890 - val_loss: 1.3422
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9433 - loss: 0.1521 - val_accuracy: 0.6631 - val_loss: 1.5371
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9445 - loss: 0.1477 - val_accuracy: 0.6602 - val_loss: 1.5711
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.71      0.85      0.77       445
#         GSVT       0.94      0.69      0.80       462
#           SB       0.97      0.99      0.98       778
#           SR       0.92      0.93      0.93       445
#
#     accuracy                           0.89      2130
#    macro avg       0.88      0.87      0.87      2130
# weighted avg       0.90      0.89      0.89      2130
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.6317 - loss: 0.9608 - val_accuracy: 0.8357 - val_loss: 0.5241
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.8653 - loss: 0.4171 - val_accuracy: 0.8327 - val_loss: 0.5825
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8814 - loss: 0.3493 - val_accuracy: 0.7582 - val_loss: 0.6238
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8951 - loss: 0.3144 - val_accuracy: 0.7271 - val_loss: 0.6667
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9047 - loss: 0.2906 - val_accuracy: 0.6661 - val_loss: 0.7750
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9033 - loss: 0.2766 - val_accuracy: 0.6590 - val_loss: 0.7981
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9075 - loss: 0.2777 - val_accuracy: 0.6614 - val_loss: 0.8016
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9079 - loss: 0.2706 - val_accuracy: 0.6573 - val_loss: 0.8203
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9445 - loss: 0.1636 - val_accuracy: 0.6802 - val_loss: 1.1526
# Epoch 73/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9420 - loss: 0.1635 - val_accuracy: 0.6719 - val_loss: 1.2605
# Epoch 74/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9402 - loss: 0.1729 - val_accuracy: 0.6514 - val_loss: 1.3464
# Epoch 75/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9409 - loss: 0.1625 - val_accuracy: 0.6626 - val_loss: 1.2545
# Epoch 76/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9469 - loss: 0.1569 - val_accuracy: 0.6473 - val_loss: 1.3310
# Epoch 77/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9437 - loss: 0.1641 - val_accuracy: 0.6719 - val_loss: 1.2411
# Epoch 78/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9424 - loss: 0.1661 - val_accuracy: 0.6496 - val_loss: 1.4231
# Epoch 79/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9476 - loss: 0.1644 - val_accuracy: 0.6655 - val_loss: 1.2606
# Epoch 80/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9434 - loss: 0.1522 - val_accuracy: 0.6543 - val_loss: 1.4489
# Epoch 81/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9469 - loss: 0.1560 - val_accuracy: 0.6573 - val_loss: 1.3308
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9476 - loss: 0.1521 - val_accuracy: 0.6585 - val_loss: 1.2979
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9450 - loss: 0.1594 - val_accuracy: 0.6508 - val_loss: 1.4327
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9435 - loss: 0.1627 - val_accuracy: 0.6514 - val_loss: 1.4664
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9479 - loss: 0.1592 - val_accuracy: 0.6549 - val_loss: 1.4831
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9424 - loss: 0.1544 - val_accuracy: 0.6631 - val_loss: 1.4136
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9414 - loss: 0.1635 - val_accuracy: 0.6590 - val_loss: 1.3940
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9437 - loss: 0.1572 - val_accuracy: 0.6508 - val_loss: 1.4186
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9464 - loss: 0.1511 - val_accuracy: 0.6496 - val_loss: 1.4855
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9425 - loss: 0.1606 - val_accuracy: 0.6579 - val_loss: 1.4147
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9436 - loss: 0.1503 - val_accuracy: 0.6508 - val_loss: 1.4524
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9522 - loss: 0.1475 - val_accuracy: 0.6631 - val_loss: 1.3119
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9446 - loss: 0.1588 - val_accuracy: 0.6485 - val_loss: 1.4159
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9445 - loss: 0.1570 - val_accuracy: 0.6526 - val_loss: 1.4144
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9494 - loss: 0.1499 - val_accuracy: 0.6502 - val_loss: 1.4644
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9433 - loss: 0.1541 - val_accuracy: 0.6837 - val_loss: 1.2593
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.9483 - loss: 0.1522 - val_accuracy: 0.6631 - val_loss: 1.2989
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9434 - loss: 0.1568 - val_accuracy: 0.6473 - val_loss: 1.4659
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9442 - loss: 0.1502 - val_accuracy: 0.6532 - val_loss: 1.4048
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.9437 - loss: 0.1586 - val_accuracy: 0.6561 - val_loss: 1.3294
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.69      0.89      0.78       445
#         GSVT       0.96      0.69      0.80       461
#           SB       0.95      0.99      0.97       778
#           SR       0.95      0.89      0.92       445
#
#     accuracy                           0.88      2129
#    macro avg       0.89      0.86      0.87      2129
# weighted avg       0.90      0.88      0.88      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9482 - loss: 0.1437 - val_accuracy: 0.6708 - val_loss: 1.1007
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9462 - loss: 0.1461 - val_accuracy: 0.6661 - val_loss: 1.2154
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9486 - loss: 0.1438 - val_accuracy: 0.6743 - val_loss: 1.1284
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9468 - loss: 0.1459 - val_accuracy: 0.6831 - val_loss: 1.0306
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.69      0.86      0.77       445
#         GSVT       0.91      0.68      0.78       461
#           SB       0.97      0.98      0.97       778
#           SR       0.92      0.92      0.92       445
#
#     accuracy                           0.88      2129
#    macro avg       0.87      0.86      0.86      2129
# weighted avg       0.89      0.88      0.88      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5852 - loss: 0.9994 - val_accuracy: 0.8110 - val_loss: 0.6403
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8645 - loss: 0.4289 - val_accuracy: 0.7171 - val_loss: 0.7328
# Epoch 3/100
# ...
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.8615 - loss: 0.4247 - val_accuracy: 0.8392 - val_loss: 0.5950
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.8670 - loss: 0.4144 - val_accuracy: 0.8392 - val_loss: 0.5949
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - accuracy: 0.8674 - loss: 0.4215 - val_accuracy: 0.8386 - val_loss: 0.5959
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.8655 - loss: 0.4222 - val_accuracy: 0.8398 - val_loss: 0.5930
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8655 - loss: 0.4187 - val_accuracy: 0.8392 - val_loss: 0.5940
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8634 - loss: 0.4156 - val_accuracy: 0.8392 - val_loss: 0.5936
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.8647 - loss: 0.4253 - val_accuracy: 0.8392 - val_loss: 0.5947
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.8717 - loss: 0.4149 - val_accuracy: 0.8398 - val_loss: 0.5944
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.8656 - loss: 0.4211 - val_accuracy: 0.8392 - val_loss: 0.5961
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.80      0.88      0.84       445
#         GSVT       0.87      0.87      0.87       461
#           SB       0.92      0.97      0.94       778
#           SR       0.93      0.74      0.83       445
#
#     accuracy                           0.88      2129
#    macro avg       0.88      0.86      0.87      2129
# weighted avg       0.88      0.88      0.88      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2518 - loss: 1.3647 - val_accuracy: 0.3351 - val_loss: 1.3548
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.3859 - loss: 1.3160 - val_accuracy: 0.5252 - val_loss: 1.3020
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.5267 - loss: 1.2661 - val_accuracy: 0.5851 - val_loss: 1.2495
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.6077 - loss: 1.2153 - val_accuracy: 0.6174 - val_loss: 1.1984
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.6250 - loss: 1.1574 - val_accuracy: 0.6373 - val_loss: 1.1480
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.6466 - loss: 1.1026 - val_accuracy: 0.6538 - val_loss: 1.0969
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.6577 - loss: 1.0436 - val_accuracy: 0.6708 - val_loss: 1.0485
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.6731 - loss: 0.9901 - val_accuracy: 0.6872 - val_loss: 1.0014
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.6777 - loss: 0.9421 - val_accuracy: 0.6995 - val_loss: 0.9574
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.6830 - loss: 0.9013 - val_accuracy: 0.7177 - val_loss: 0.9145
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.8614 - loss: 0.4411 - val_accuracy: 0.8439 - val_loss: 0.5384
# Epoch 75/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.8650 - loss: 0.4253 - val_accuracy: 0.8445 - val_loss: 0.5388
# Epoch 76/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.8629 - loss: 0.4405 - val_accuracy: 0.8445 - val_loss: 0.5400
# Epoch 77/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8633 - loss: 0.4365 - val_accuracy: 0.8445 - val_loss: 0.5404
# Epoch 78/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.8654 - loss: 0.4257 - val_accuracy: 0.8439 - val_loss: 0.5411
# Epoch 79/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8645 - loss: 0.4291 - val_accuracy: 0.8451 - val_loss: 0.5395
# Epoch 80/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.8684 - loss: 0.4240 - val_accuracy: 0.8439 - val_loss: 0.5393
# Epoch 81/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.8697 - loss: 0.4215 - val_accuracy: 0.8439 - val_loss: 0.5392
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.8687 - loss: 0.4218 - val_accuracy: 0.8433 - val_loss: 0.5402
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.8674 - loss: 0.4203 - val_accuracy: 0.8433 - val_loss: 0.5416
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.8705 - loss: 0.4200 - val_accuracy: 0.8451 - val_loss: 0.5418
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.8682 - loss: 0.4242 - val_accuracy: 0.8445 - val_loss: 0.5429
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.8719 - loss: 0.4110 - val_accuracy: 0.8451 - val_loss: 0.5428
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.8623 - loss: 0.4257 - val_accuracy: 0.8439 - val_loss: 0.5437
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.8703 - loss: 0.4174 - val_accuracy: 0.8433 - val_loss: 0.5451
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8678 - loss: 0.4178 - val_accuracy: 0.8421 - val_loss: 0.5446
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8672 - loss: 0.4167 - val_accuracy: 0.8421 - val_loss: 0.5455
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8680 - loss: 0.4120 - val_accuracy: 0.8427 - val_loss: 0.5437
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8705 - loss: 0.4140 - val_accuracy: 0.8427 - val_loss: 0.5431
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8691 - loss: 0.3990 - val_accuracy: 0.8433 - val_loss: 0.5443
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8706 - loss: 0.4106 - val_accuracy: 0.8421 - val_loss: 0.5445
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8707 - loss: 0.4047 - val_accuracy: 0.8421 - val_loss: 0.5456
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.8736 - loss: 0.4020 - val_accuracy: 0.8421 - val_loss: 0.5459
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8700 - loss: 0.4102 - val_accuracy: 0.8415 - val_loss: 0.5467
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.8725 - loss: 0.4033 - val_accuracy: 0.8415 - val_loss: 0.5479
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.8760 - loss: 0.3974 - val_accuracy: 0.8427 - val_loss: 0.5486
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.8705 - loss: 0.4043 - val_accuracy: 0.8421 - val_loss: 0.5487
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.79      0.86      0.82       445
#         GSVT       0.89      0.87      0.88       462
#           SB       0.90      0.97      0.93       777
#           SR       0.93      0.74      0.82       445
#
#     accuracy                           0.88      2129
#    macro avg       0.88      0.86      0.86      2129
# weighted avg       0.88      0.88      0.87      2129
#
# Optimizer: adagrad - Mean CV Accuracy: 0.8766663312911988
#
# Final Results:
# adam: 0.8807058930397034
# sgd: 0.8777936220169067
# rmsprop: 0.8843696236610412
# adagrad: 0.8766663312911988
