# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical

# Biosppy for signal processing
from biosppy.signals import ecg

# Randomly seeding
tf.random.set_seed(6950)

# Constants
SAMPLING_RATE = 500  # Hz
ecg_folder = "../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}
# Out:
# 2024-11-29 08:37:55.328613: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 08:37:55.339084: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 08:37:55.342288: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 08:37:55.351081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-29 08:37:55.854935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def extract_comprehensive_features(ecg_signal):
    """
    Extract comprehensive features from entire ECG signal
    """
    # Process ECG signal
    try:
        ecg_processed = ecg.ecg(signal=ecg_signal, sampling_rate=SAMPLING_RATE, show=False)

        # R-peak related features
        rpeaks = ecg_processed['rpeaks']
        heart_rate = ecg_processed['heart_rate']

        # Time domain features
        features = [
            # Statistical features of raw signal
            np.mean(ecg_signal),
            np.std(ecg_signal),
            np.median(ecg_signal),
            np.min(ecg_signal),
            np.max(ecg_signal),

            # R-peak related features
            len(rpeaks),  # Number of R peaks
            np.mean(heart_rate) if len(heart_rate) > 0 else 0,
            np.std(heart_rate) if len(heart_rate) > 0 else 0,

            # R-R interval features
            np.mean(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.std(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,

            # Additional signal characteristics
            np.percentile(ecg_signal, 25),
            np.percentile(ecg_signal, 75),
        ]

        return features

    except Exception as e:
        print(f"Error processing signal: {e}")
        return [0] * 12


def prepare_dataset(ecg_folder, diagnostics_df):
    """
    Prepare dataset by processing whole ECG signals
    """
    signals = []
    signal_features = []
    signal_labels = []

    for _, row in diagnostics_df.iterrows():
        file_name = row['FileName']
        rhythm_label = row['Rhythm']

        # Skip if rhythm label is invalid
        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            continue

        # Load ECG file (Lead 2)
        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            continue

        # Load entire signal
        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)

        # Extract features from whole signal
        features = extract_comprehensive_features(ecg_data)

        signals.append(ecg_data)
        signal_features.append(features)
        signal_labels.append(rhythm_label)

    return (np.array(signals),
            np.array(signal_features),
            np.array(signal_labels))

# %%
# Load diagnostics
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)

# Prepare dataset
raw_signals, signal_features, signal_labels = prepare_dataset(ecg_folder, diagnostics_df)
print(raw_signals.shape, signal_features.shape, signal_labels.shape)
# Out:
# (10646, 5000) (10646, 12) (10646,)

# %%
# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(signal_labels)
onehot_labels = to_categorical(encoded_labels)

# Scale features
feature_scaler = StandardScaler()
scaled_features = feature_scaler.fit_transform(signal_features)

# Pad signals for neural network input
max_length = max(len(signal) for signal in raw_signals)
padded_signals = np.array([np.pad(signal, (0, max_length - len(signal))) for signal in raw_signals])


# Create model with multiple architectures
def create_hybrid_model(input_shape, num_classes):
    model = Sequential([
        # 1D Convolutional layers
        Conv1D(64, 3, activation='relu', input_shape=input_shape),
        MaxPooling1D(2),
        Conv1D(32, 3, activation='relu'),
        MaxPooling1D(2),

        # LSTM layer
        LSTM(50, return_sequences=False),

        # Dense layers with features
        Dense(64, activation='relu', input_shape=(scaled_features.shape[1],)),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.2),

        # Output layer
        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model


# Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = []

for train_index, test_index in skf.split(padded_signals, signal_labels):
    # Split data
    X_train_signals = padded_signals[train_index]
    X_train_features = scaled_features[train_index]
    y_train = onehot_labels[train_index]

    X_test_signals = padded_signals[test_index]
    X_test_features = scaled_features[test_index]
    y_test = onehot_labels[test_index]

    # Create and train model
    model = create_hybrid_model(
        (X_train_signals.shape[1], 1),
        onehot_labels.shape[1]
    )

    # Training
    history = model.fit(
        [X_train_signals.reshape(-1, X_train_signals.shape[1], 1), X_train_features],
        y_train,
        epochs=50,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    # Evaluate
    y_pred = model.predict([
        X_test_signals.reshape(-1, X_test_signals.shape[1], 1),
        X_test_features
    ])
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    # Compute accuracy
    accuracy = np.mean(y_pred_classes == y_test_classes)
    cv_scores.append(accuracy)

    print("\nClassification Report:")
    print(classification_report(
        y_test_classes,
        y_pred_classes,
        target_names=label_encoder.classes_
    ))

# Print cross-validation results
print("\nCross-Validation Scores:", cv_scores)
print("Mean CV Accuracy:", np.mean(cv_scores))
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732848168.152546  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.182687  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.183872  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.186484  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.187542  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.188906  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.285629  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.286735  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732848168.287772  504286 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-29 08:42:48.289013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5437 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 2024-11-29 08:42:49.752489: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1732848169.862713  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.894763  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.895411  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.896048  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.906182  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.908448  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.910930  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.918394  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.920680  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.921387  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.935072  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.937280  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.940403  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.950066  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.952114  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.953957  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.956174  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.956911  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.962965  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.965666  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.968608  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.970980  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.971897  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.972841  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.973758  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.974838  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.975579  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.978521  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.979470  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.980536  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.981741  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.991869  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848169.992624  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.287490  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.288215  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.289267  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.290195  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.290963  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.291694  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.292475  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.293485  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.294980  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.295760  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.296409  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.297225  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.297874  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.298549  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.299527  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.300397  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.301258  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.301946  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.302761  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.303553  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.304410  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.305208  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.306064  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.306854  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.307742  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.308564  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.309465  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.310291  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.311273  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.312085  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.312903  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.315243  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.316125  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.318409  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#   1/213 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.3125 - loss: 1.4186
# W0000 00:00:1732848170.972381  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.973361  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.974523  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.975563  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.976571  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.980907  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.982655  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.983806  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.984870  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.986470  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.987318  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.988625  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.990150  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.991061  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.992382  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.994070  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.995124  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.996516  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848170.998356  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.000604  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.002779  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.003988  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.010396  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.012235  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.014905  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.065309  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.066155  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.066901  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.067670  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.068516  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.069283  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.070049  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.071044  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.073263  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.074271  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.075092  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.075897  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.079381  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.080242  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.081136  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.082475  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.083317  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.084017  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.084973  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.091207  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.100938  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.101959  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.108214  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.132687  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.133456  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.134230  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.135023  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.136464  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.137303  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.138267  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.139201  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.140244  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.141239  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.142237  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.143425  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.144663  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.145887  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.146861  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.147780  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.148686  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.149694  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.151202  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.153062  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.154246  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848171.155282  507255 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 212/213 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3667 - loss: 1.3364
# W0000 00:00:1732848179.791426  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.792115  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.792693  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.793287  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.793905  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.794533  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.795238  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.795879  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.796922  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.797569  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.798250  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.798937  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.799709  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.800471  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.801242  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.802016  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.802812  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.803461  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.804120  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.804909  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.805699  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.806559  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.807395  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.808439  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.809397  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.810336  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.810984  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.811938  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.812797  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.813756  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.814829  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.816176  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.816822  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.831530  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.832184  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.832737  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.833389  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.834070  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.834725  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.835424  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.836114  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.836821  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.837524  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.838129  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.838851  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.839436  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.840029  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.840737  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.841496  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.842258  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.842868  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.843613  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.844393  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.845155  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.845863  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.846621  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.847332  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.848110  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.849256  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.850287  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.851030  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.851867  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.852599  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.853339  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.854137  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.854911  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.856033  507256 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.899362  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.903091  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.907272  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.911697  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.916187  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.924754  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.929457  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.934223  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.938677  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.943086  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.947631  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.952321  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.954638  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.958659  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.963143  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.967914  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.972521  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.977403  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.982381  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.987745  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3667 - loss: 1.3363
# W0000 00:00:1732848179.992408  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848179.996975  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.001787  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.003876  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.006077  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.013951  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.014647  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.015494  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.016616  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.017174  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.017859  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.018547  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.019255  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.019977  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.020921  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.021655  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.022366  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.023119  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.023873  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.024664  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.025521  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.026282  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.026905  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.027741  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.028565  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.029425  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.030298  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.033209  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.038833  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.039542  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.040261  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.040984  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.041754  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.042550  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.043395  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.044237  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.045153  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.046038  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.046924  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.047959  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.049514  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.050812  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.051689  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.052515  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.053327  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.054532  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.057519  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.062714  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.067010  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.068067  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.263340  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.268578  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.269182  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.269764  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.270334  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.270908  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.271484  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.272063  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.272668  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.273276  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.273926  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.274539  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.275194  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.275848  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.276546  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.277237  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.278168  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.278981  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.279760  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.280541  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.281359  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.282416  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.283742  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.284629  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.285710  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.286589  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.287573  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.289548  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.290628  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.291674  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.308362  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.309162  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.309847  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.310604  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.311308  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.311997  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.312792  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.313474  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.314204  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.314889  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.315602  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.316919  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.317723  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.318445  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.319299  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.320155  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.321380  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.322351  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.323142  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.323832  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.324599  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.325450  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.326212  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.326988  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.327695  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.328439  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.329144  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.329885  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.331166  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.332138  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.332906  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.333889  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.334846  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.336034  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848180.336978  507252 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - accuracy: 0.3668 - loss: 1.3362 - val_accuracy: 0.2477 - val_loss: 1.4036
# Epoch 2/50
#   3/213 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.4479 - loss: 1.2313
# W0000 00:00:1732848181.249213  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.249817  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.250340  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.250860  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.251584  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.252084  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.252604  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.253114  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.253628  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.254139  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.254741  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.255327  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.255912  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.256451  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.257041  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.257913  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.258503  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.259058  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.259570  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.260195  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.260738  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.261282  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.261866  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1732848181.262442  507258 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
#           SB       0.95      0.88      0.92       778
#           SR       0.83      0.74      0.78       445
#
#     accuracy                           0.81      2129
#    macro avg       0.81      0.80      0.79      2129
# weighted avg       0.83      0.81      0.81      2129
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.3852 - loss: 1.3232 - val_accuracy: 0.2330 - val_loss: 1.4645
# Epoch 2/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.3920 - loss: 1.2921 - val_accuracy: 0.2518 - val_loss: 1.4107
# Epoch 3/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.4003 - loss: 1.2726 - val_accuracy: 0.3316 - val_loss: 1.3613
# Epoch 4/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.4313 - loss: 1.2346 - val_accuracy: 0.5411 - val_loss: 1.2534
# Epoch 5/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.4934 - loss: 1.1375 - val_accuracy: 0.6015 - val_loss: 1.0958
# Epoch 6/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.5554 - loss: 1.0309 - val_accuracy: 0.5921 - val_loss: 1.0610
# Epoch 7/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6066 - loss: 0.9264 - val_accuracy: 0.5968 - val_loss: 1.0806
# Epoch 8/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6202 - loss: 0.8826 - val_accuracy: 0.6502 - val_loss: 0.9865
# Epoch 9/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6453 - loss: 0.8346 - val_accuracy: 0.6326 - val_loss: 0.9920
# Epoch 10/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.6640 - loss: 0.8147 - val_accuracy: 0.6520 - val_loss: 0.9882
# Epoch 11/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6772 - loss: 0.7722 - val_accuracy: 0.6626 - val_loss: 0.9801
# Epoch 12/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6825 - loss: 0.7604 - val_accuracy: 0.6678 - val_loss: 0.9483
# Epoch 13/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6994 - loss: 0.7431 - val_accuracy: 0.6596 - val_loss: 0.9541
# Epoch 14/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7029 - loss: 0.7394 - val_accuracy: 0.6643 - val_loss: 0.9576
# Epoch 15/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7106 - loss: 0.7065 - val_accuracy: 0.6673 - val_loss: 0.9216
# Epoch 16/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7228 - loss: 0.6941 - val_accuracy: 0.6608 - val_loss: 0.9557
# Epoch 17/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.7264 - loss: 0.6672 - val_accuracy: 0.6485 - val_loss: 0.9228
# Epoch 18/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7361 - loss: 0.6614 - val_accuracy: 0.7406 - val_loss: 0.8063
# Epoch 19/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7322 - loss: 0.6470 - val_accuracy: 0.7265 - val_loss: 0.8033
# Epoch 20/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7480 - loss: 0.6295 - val_accuracy: 0.7218 - val_loss: 0.8232
# Epoch 21/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7609 - loss: 0.6143 - val_accuracy: 0.6614 - val_loss: 0.8869
# Epoch 22/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7577 - loss: 0.6067 - val_accuracy: 0.7318 - val_loss: 0.7513
# Epoch 23/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7699 - loss: 0.5764 - val_accuracy: 0.6655 - val_loss: 0.8224
# Epoch 24/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7898 - loss: 0.5559 - val_accuracy: 0.6843 - val_loss: 0.7502
# Epoch 25/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7879 - loss: 0.5512 - val_accuracy: 0.6420 - val_loss: 0.8377
# Epoch 26/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7992 - loss: 0.5287 - val_accuracy: 0.6344 - val_loss: 0.8470
# Epoch 27/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.8161 - loss: 0.5054 - val_accuracy: 0.6714 - val_loss: 0.8199
# Epoch 28/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8139 - loss: 0.4813 - val_accuracy: 0.6737 - val_loss: 0.8505
# Epoch 29/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8238 - loss: 0.4682 - val_accuracy: 0.6467 - val_loss: 0.8353
# Epoch 30/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8195 - loss: 0.4621 - val_accuracy: 0.6608 - val_loss: 0.8155
# Epoch 31/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.8369 - loss: 0.4354 - val_accuracy: 0.6567 - val_loss: 0.8747
# Epoch 32/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8328 - loss: 0.4484 - val_accuracy: 0.6843 - val_loss: 0.7966
# Epoch 33/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8474 - loss: 0.4187 - val_accuracy: 0.7230 - val_loss: 0.7621
# Epoch 34/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8687 - loss: 0.3610 - val_accuracy: 0.6714 - val_loss: 0.8686
# Epoch 35/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8603 - loss: 0.3880 - val_accuracy: 0.6743 - val_loss: 0.8713
# Epoch 36/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.8645 - loss: 0.3695 - val_accuracy: 0.6901 - val_loss: 0.7979
# Epoch 37/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.8656 - loss: 0.3594 - val_accuracy: 0.7142 - val_loss: 0.8242
# Epoch 38/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8656 - loss: 0.3525 - val_accuracy: 0.6772 - val_loss: 0.8938
# Epoch 39/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8804 - loss: 0.3293 - val_accuracy: 0.6978 - val_loss: 0.8468
# Epoch 40/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8763 - loss: 0.3416 - val_accuracy: 0.7101 - val_loss: 0.8087
# Epoch 41/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8761 - loss: 0.3214 - val_accuracy: 0.5898 - val_loss: 1.1287
# Epoch 42/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8595 - loss: 0.3827 - val_accuracy: 0.6766 - val_loss: 0.9923
# Epoch 43/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8843 - loss: 0.3167 - val_accuracy: 0.6719 - val_loss: 0.9476
# Epoch 44/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8901 - loss: 0.3116 - val_accuracy: 0.6414 - val_loss: 0.9767
# Epoch 45/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8929 - loss: 0.3017 - val_accuracy: 0.6778 - val_loss: 0.9690
# Epoch 46/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.9000 - loss: 0.2885 - val_accuracy: 0.6180 - val_loss: 1.0350
# Epoch 47/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8857 - loss: 0.3079 - val_accuracy: 0.6579 - val_loss: 1.1138
# Epoch 48/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8973 - loss: 0.2936 - val_accuracy: 0.6185 - val_loss: 1.2855
# Epoch 49/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8893 - loss: 0.3048 - val_accuracy: 0.6520 - val_loss: 1.2315
# Epoch 50/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9110 - loss: 0.2641 - val_accuracy: 0.6772 - val_loss: 1.0766
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.69      0.86      0.77       445
#         GSVT       0.84      0.61      0.71       461
#           SB       0.91      0.97      0.94       778
#           SR       0.87      0.80      0.83       445
#
#     accuracy                           0.83      2129
#    macro avg       0.83      0.81      0.81      2129
# weighted avg       0.84      0.83      0.83      2129
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.3628 - loss: 1.3565 - val_accuracy: 0.2523 - val_loss: 1.4627
# Epoch 2/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.3976 - loss: 1.2895 - val_accuracy: 0.2488 - val_loss: 1.4935
# Epoch 3/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.4172 - loss: 1.2618 - val_accuracy: 0.5246 - val_loss: 1.2702
# Epoch 4/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.4781 - loss: 1.1627 - val_accuracy: 0.4836 - val_loss: 1.3177
# Epoch 5/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.5415 - loss: 1.0640 - val_accuracy: 0.5669 - val_loss: 1.1122
# Epoch 6/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6243 - loss: 0.9001 - val_accuracy: 0.5775 - val_loss: 1.0861
# Epoch 7/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6348 - loss: 0.8772 - val_accuracy: 0.5710 - val_loss: 1.0974
# Epoch 8/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.6639 - loss: 0.8198 - val_accuracy: 0.6620 - val_loss: 0.9543
# Epoch 9/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6806 - loss: 0.7912 - val_accuracy: 0.6420 - val_loss: 1.0602
# Epoch 10/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6910 - loss: 0.7642 - val_accuracy: 0.6978 - val_loss: 0.8949
# Epoch 11/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7017 - loss: 0.7471 - val_accuracy: 0.6872 - val_loss: 0.9239
# Epoch 12/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7077 - loss: 0.7210 - val_accuracy: 0.7230 - val_loss: 0.8482
# Epoch 13/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7121 - loss: 0.6939 - val_accuracy: 0.7048 - val_loss: 0.8848
# Epoch 14/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7285 - loss: 0.6706 - val_accuracy: 0.6749 - val_loss: 0.9571
# Epoch 15/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.7398 - loss: 0.6651 - val_accuracy: 0.6678 - val_loss: 0.9569
# Epoch 16/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7464 - loss: 0.6539 - val_accuracy: 0.6755 - val_loss: 0.9201
# Epoch 17/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7650 - loss: 0.6091 - val_accuracy: 0.6403 - val_loss: 0.9902
# Epoch 18/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7695 - loss: 0.5984 - val_accuracy: 0.6972 - val_loss: 0.8182
# Epoch 19/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.7839 - loss: 0.5661 - val_accuracy: 0.5687 - val_loss: 1.1710
# Epoch 20/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.7855 - loss: 0.5636 - val_accuracy: 0.6731 - val_loss: 0.8480
# Epoch 21/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8061 - loss: 0.5305 - val_accuracy: 0.6373 - val_loss: 0.9728
# Epoch 22/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8319 - loss: 0.4794 - val_accuracy: 0.6408 - val_loss: 0.9875
# Epoch 23/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.8519 - loss: 0.4421 - val_accuracy: 0.6279 - val_loss: 0.9832
# Epoch 24/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8653 - loss: 0.4051 - val_accuracy: 0.6485 - val_loss: 0.9296
# Epoch 25/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8791 - loss: 0.3666 - val_accuracy: 0.6092 - val_loss: 1.0932
# Epoch 26/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8797 - loss: 0.3448 - val_accuracy: 0.6227 - val_loss: 0.9147
# Epoch 27/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8993 - loss: 0.3066 - val_accuracy: 0.6344 - val_loss: 1.0279
# Epoch 28/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8947 - loss: 0.3063 - val_accuracy: 0.6397 - val_loss: 1.0096
# Epoch 29/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9010 - loss: 0.3066 - val_accuracy: 0.5822 - val_loss: 1.2095
# Epoch 30/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9072 - loss: 0.2921 - val_accuracy: 0.6362 - val_loss: 1.0714
# Epoch 31/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9128 - loss: 0.2750 - val_accuracy: 0.5992 - val_loss: 1.2513
# Epoch 32/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9080 - loss: 0.2726 - val_accuracy: 0.6150 - val_loss: 1.3595
# Epoch 33/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9164 - loss: 0.2584 - val_accuracy: 0.6209 - val_loss: 1.4287
# Epoch 34/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9230 - loss: 0.2329 - val_accuracy: 0.6097 - val_loss: 1.4611
# Epoch 35/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9198 - loss: 0.2312 - val_accuracy: 0.6174 - val_loss: 1.4869
# Epoch 36/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9230 - loss: 0.2322 - val_accuracy: 0.5980 - val_loss: 1.4167
# Epoch 37/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9177 - loss: 0.2466 - val_accuracy: 0.5792 - val_loss: 1.6993
# Epoch 38/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9319 - loss: 0.2246 - val_accuracy: 0.6244 - val_loss: 1.4678
# Epoch 39/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9351 - loss: 0.1949 - val_accuracy: 0.6015 - val_loss: 1.8507
# Epoch 40/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9059 - loss: 0.3049 - val_accuracy: 0.5839 - val_loss: 1.5580
# Epoch 41/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9270 - loss: 0.2111 - val_accuracy: 0.6080 - val_loss: 1.7123
# Epoch 42/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9333 - loss: 0.1992 - val_accuracy: 0.6320 - val_loss: 1.3906
# Epoch 43/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9262 - loss: 0.1986 - val_accuracy: 0.6045 - val_loss: 1.7392
# Epoch 44/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9388 - loss: 0.1817 - val_accuracy: 0.6209 - val_loss: 1.3394
# Epoch 45/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.9251 - loss: 0.2260 - val_accuracy: 0.6150 - val_loss: 1.2764
# Epoch 46/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9336 - loss: 0.2034 - val_accuracy: 0.6080 - val_loss: 1.4568
# Epoch 47/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9439 - loss: 0.1761 - val_accuracy: 0.6068 - val_loss: 1.1262
# Epoch 48/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8981 - loss: 0.3037 - val_accuracy: 0.6273 - val_loss: 1.4354
# Epoch 49/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9365 - loss: 0.1998 - val_accuracy: 0.6309 - val_loss: 1.3100
# Epoch 50/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9431 - loss: 0.1719 - val_accuracy: 0.6315 - val_loss: 1.4070
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.70      0.97      0.81       445
#         GSVT       0.95      0.62      0.75       462
#           SB       0.94      0.98      0.96       777
#           SR       0.95      0.85      0.90       445
#
#     accuracy                           0.87      2129
#    macro avg       0.88      0.86      0.86      2129
# weighted avg       0.89      0.87      0.87      2129
#
#
# Cross-Validation Scores: [0.7009389671361502, 0.8407703147017379, 0.8097698449976515, 0.8341944574917802, 0.873179896665101]
# Mean CV Accuracy: 0.8117706961984842
