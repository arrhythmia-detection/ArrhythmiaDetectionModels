# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm
import tensorflow as tf
# noinspection PyUnresolvedReferences
from tensorflow.keras.models import Sequential
# noinspection PyUnresolvedReferences
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, BatchNormalization

# Constants
SAMPLING_RATE = 500  # Hz
WINDOW_SIZE = 2 * SAMPLING_RATE
STEP_SIZE = 1 * SAMPLING_RATE
ecg_folder = "../../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}

# Load diagnostics data
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)
# Out:
# 2024-11-27 12:04:12.482559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-27 12:04:12.493308: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-27 12:04:12.496560: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 12:04:12.505958: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-27 12:04:13.010730: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
diagnostics_df
# Out:
#                          FileName Rhythm       Beat  PatientAge  Gender  \
# 0      MUSE_20180113_171327_27000   AFIB   RBBB TWC          85    MALE
# 1      MUSE_20180112_073319_29000     SB        TWC          59  FEMALE
# 2      MUSE_20180111_165520_97000     SR       NONE          20  FEMALE
# 3      MUSE_20180113_121940_44000     SB       NONE          66    MALE
# 4      MUSE_20180112_122850_57000   AFIB  STDD STTC          73  FEMALE
# ...                           ...    ...        ...         ...     ...
# 10641  MUSE_20181222_204306_99000   GSVT       NONE          80  FEMALE
# 10642  MUSE_20181222_204309_22000   GSVT       NONE          81  FEMALE
# 10643  MUSE_20181222_204310_31000   GSVT       NONE          39    MALE
# 10644  MUSE_20181222_204312_58000   GSVT       NONE          76    MALE
# 10645  MUSE_20181222_204314_78000   GSVT       NONE          75    MALE
#
#        VentricularRate  AtrialRate  QRSDuration  QTInterval  QTCorrected  \
# 0                  117         234          114         356          496
# 1                   52          52           92         432          401
# 2                   67          67           82         382          403
# 3                   53          53           96         456          427
# 4                  162         162          114         252          413
# ...                ...         ...          ...         ...          ...
# 10641              196          73          168         284          513
# 10642              162          81          162         294          482
# 10643              152          92          152         340          540
# 10644              175         178          128         310          529
# 10645              117         104          140         312          435
#
#        RAxis  TAxis  QRSCount  QOnset  QOffset  TOffset
# 0         81    -27        19     208      265      386
# 1         76     42         8     215      261      431
# 2         88     20        11     224      265      415
# 3         34      3         9     219      267      447
# 4         68    -40        26     228      285      354
# ...      ...    ...       ...     ...      ...      ...
# 10641    258    244        32     177      261      319
# 10642    110    -75        27     173      254      320
# 10643    250     38        25     208      284      378
# 10644     98    -83        29     205      269      360
# 10645    263    144        19     208      278      364
#
# [10646 rows x 16 columns]

# %%
from scipy.signal import butter, filtfilt

# Define a Butterworth bandpass filter
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Apply the Butterworth bandpass filter
def bandpass_filter(data, lowcut=0.5, highcut=50.0, fs=500, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    filtered_data = filtfilt(b, a, data)
    return filtered_data


def preprocess_ecg_data(ecg_folder, diagnostics_df):
    segments = []
    segment_labels = []

    for _, row in tqdm(diagnostics_df.iterrows(), total=diagnostics_df.shape[0]):
        file_name = row['FileName']
        rhythm_label = row['Rhythm']

        # Skip if rhythm label is invalid
        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            print("Invalid rhythm label", rhythm_label)
            continue

        # Load ECG file
        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            print("File not found", ecg_file)
            continue

        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)

        ecg_data = bandpass_filter(ecg_data, lowcut=0.5, highcut=50.0, fs=500)

        # Normalize the signal
        # ecg_data = (ecg_data - np.mean(ecg_data)) / np.std(ecg_data)
        # print(len(ecg_data))
        # Segment the data using sliding window
        for start in range(0, len(ecg_data) - WINDOW_SIZE + 1, STEP_SIZE):
            segment = ecg_data[start:start + WINDOW_SIZE]
            segments.append(segment)
            segment_labels.append(rhythm_label)

    return np.array(segments), np.array(segment_labels)


# Preprocess data
segments, segment_labels = preprocess_ecg_data(ecg_folder, diagnostics_df)
segments
# Out:
# 100%|██████████| 10646/10646 [00:58<00:00, 183.38it/s]
# array([[ -54.80315802,  -52.03122887,  -50.81890882, ..., -106.69487746,
#          -93.32025106,  -80.6932936 ],
#        [  16.71588221,   26.90299297,   31.29498008, ...,   38.26315102,
#           33.3374666 ,   26.74318279],
#        [ -70.11533772,  -62.67772659,  -59.09794289, ...,  -30.88801473,
#          -33.07046557,  -33.53648724],
#        ...,
#        [  -7.04697507,   -2.45773578,    1.7604805 , ..., -157.73240267,
#         -155.50880072, -153.71140666],
#        [ -35.10222605,  -30.23766349,  -24.70039684, ..., -130.82928096,
#         -124.10242375, -117.10045159],
#        [-152.25653906, -150.93842796, -149.45201828, ...,   86.40206903,
#           82.0118788 ,   77.65999621]])

# %%
# Encode labels
label_encoder = LabelEncoder()
segment_labels_encoded = label_encoder.fit_transform(segment_labels)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(segments, segment_labels_encoded, test_size=0.2, random_state=42)

# Decision Tree
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train.reshape(X_train.shape[0], -1), y_train)
y_pred_dt = dt.predict(X_test.reshape(X_test.shape[0], -1))
print("Decision Tree Classification Report:")
print(classification_report(y_test, y_pred_dt, target_names=label_encoder.classes_))
print("Depth of the tree", dt.get_depth())
print("Leaf nodes of the tree", dt.get_n_leaves())
# Out:
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.36      0.36      0.36      3963
#         GSVT       0.59      0.58      0.59      4051
#           SB       0.71      0.71      0.71      7037
#           SR       0.48      0.50      0.49      4112
#
#     accuracy                           0.57     19163
#    macro avg       0.54      0.54      0.54     19163
# weighted avg       0.57      0.57      0.57     19163
#
# Depth of the tree 76
# Leaf nodes of the tree 11490

# %%
# MLP
mlp = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
mlp.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mlp.fit(X_train, y_train, epochs=100, batch_size=1024, validation_data=(X_test, y_test))
y_pred_mlp = np.argmax(mlp.predict(X_test), axis=1)
print("MLP Classification Report:")
print(classification_report(y_test, y_pred_mlp, target_names=label_encoder.classes_))
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1
100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7271 - loss: 0.6871 - val_accuracy: 0.7920 - val_loss: 0.5581
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7254 - loss: 0.6904 - val_accuracy: 0.7901 - val_loss: 0.5591
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7234 - loss: 0.6935 - val_accuracy: 0.7929 - val_loss: 0.5578
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7233 - loss: 0.6906 - val_accuracy: 0.7900 - val_loss: 0.5559
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.6813 - val_accuracy: 0.7907 - val_loss: 0.5514
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7257 - loss: 0.6891 - val_accuracy: 0.7929 - val_loss: 0.5512
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7263 - loss: 0.6883 - val_accuracy: 0.7931 - val_loss: 0.5519
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7280 - loss: 0.6841 - val_accuracy: 0.7952 - val_loss: 0.5467
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7292 - loss: 0.6858 - val_accuracy: 0.7941 - val_loss: 0.5493
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7294 - loss: 0.6788 - val_accuracy: 0.7964 - val_loss: 0.5467
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7293 - loss: 0.6823 - val_accuracy: 0.7939 - val_loss: 0.5465
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7321 - loss: 0.6795 - val_accuracy: 0.7948 - val_loss: 0.5442
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7297 - loss: 0.6787 - val_accuracy: 0.7982 - val_loss: 0.5433
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7324 - loss: 0.6758 - val_accuracy: 0.7946 - val_loss: 0.5457
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7313 - loss: 0.6726 - val_accuracy: 0.7967 - val_loss: 0.5435
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7358 - loss: 0.6722 - val_accuracy: 0.7961 - val_loss: 0.5423
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7327 - loss: 0.6752 - val_accuracy: 0.7984 - val_loss: 0.5416
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7335 - loss: 0.6777 - val_accuracy: 0.7963 - val_loss: 0.5404
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7308 - loss: 0.6726 - val_accuracy: 0.7966 - val_loss: 0.5404
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7362 - loss: 0.6704 - val_accuracy: 0.7987 - val_loss: 0.5368
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7350 - loss: 0.6702 - val_accuracy: 0.7990 - val_loss: 0.5375
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7366 - loss: 0.6692 - val_accuracy: 0.7985 - val_loss: 0.5403
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7381 - loss: 0.6691 - val_accuracy: 0.7986 - val_loss: 0.5387
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7348 - loss: 0.6711 - val_accuracy: 0.7992 - val_loss: 0.5373
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7346 - loss: 0.6715 - val_accuracy: 0.8003 - val_loss: 0.5379
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7358 - loss: 0.6695 - val_accuracy: 0.7994 - val_loss: 0.5342
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.6677 - val_accuracy: 0.8032 - val_loss: 0.5338
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.6646 - val_accuracy: 0.8010 - val_loss: 0.5334
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7395 - loss: 0.6613 - val_accuracy: 0.8008 - val_loss: 0.5324
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.6686 - val_accuracy: 0.8032 - val_loss: 0.5311
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7350 - loss: 0.6722 - val_accuracy: 0.8013 - val_loss: 0.5324
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7389 - loss: 0.6663 - val_accuracy: 0.7995 - val_loss: 0.5317
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7422 - loss: 0.6543 - val_accuracy: 0.8028 - val_loss: 0.5296
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7359 - loss: 0.6658 - val_accuracy: 0.8033 - val_loss: 0.5306
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7393 - loss: 0.6682 - val_accuracy: 0.8024 - val_loss: 0.5317
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7409 - loss: 0.6593 - val_accuracy: 0.8036 - val_loss: 0.5311
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7391 - loss: 0.6629 - val_accuracy: 0.8008 - val_loss: 0.5289
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7377 - loss: 0.6656 - val_accuracy: 0.8035 - val_loss: 0.5298
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7388 - loss: 0.6644 - val_accuracy: 0.8048 - val_loss: 0.5274
# 599/599 ━━━━━━━━━━━━━━━━━━━━ 1s 848us/step
# MLP Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.59      0.64      0.62      3963
#         GSVT       0.85      0.80      0.82      4051
#           SB       0.90      0.96      0.93      7037
#           SR       0.80      0.70      0.75      4112
#
#     accuracy                           0.80     19163
#    macro avg       0.79      0.78      0.78     19163
# weighted avg       0.81      0.80      0.80     19163

# %%
# Standardize input shape for CNN
X_train_cnn = X_train[..., np.newaxis]
X_test_cnn = X_test[..., np.newaxis]

# CNN
cnn = Sequential([
    Conv1D(64, kernel_size=3, activation='relu', input_shape=(X_train_cnn.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Conv1D(128, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
cnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn.fit(X_train_cnn, y_train, epochs=50, batch_size=64, validation_data=(X_test_cnn, y_test))
y_pred_cnn = np.argmax(cnn.predict(X_test_cnn), axis=1)
print("CNN Classification Report:")
print(classification_report(y_test, y_pred_cnn, target_names=label_encoder.classes_))
# Out:
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4138 - loss: 3.7438 - val_accuracy: 0.7395 - val_loss: 0.7103
# Epoch 2/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6801 - loss: 0.8278 - val_accuracy: 0.7853 - val_loss: 0.5922
# Epoch 3/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7369 - loss: 0.6960 - val_accuracy: 0.8021 - val_loss: 0.5351
# Epoch 4/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7669 - loss: 0.6236 - val_accuracy: 0.8103 - val_loss: 0.5115
# Epoch 5/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7887 - loss: 0.5640 - val_accuracy: 0.8212 - val_loss: 0.5006
# Epoch 6/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8077 - loss: 0.5166 - val_accuracy: 0.8301 - val_loss: 0.4708
# Epoch 7/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8262 - loss: 0.4674 - val_accuracy: 0.8293 - val_loss: 0.4707
# Epoch 8/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8412 - loss: 0.4219 - val_accuracy: 0.8300 - val_loss: 0.4621
# Epoch 9/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8548 - loss: 0.3835 - val_accuracy: 0.8340 - val_loss: 0.4560
# Epoch 10/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8709 - loss: 0.3450 - val_accuracy: 0.8312 - val_loss: 0.5098
# Epoch 11/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8806 - loss: 0.3201 - val_accuracy: 0.8367 - val_loss: 0.5029
# Epoch 12/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8868 - loss: 0.3032 - val_accuracy: 0.8289 - val_loss: 0.4889
# Epoch 13/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8982 - loss: 0.2700 - val_accuracy: 0.8371 - val_loss: 0.5530
# Epoch 14/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9038 - loss: 0.2585 - val_accuracy: 0.8351 - val_loss: 0.6170
# Epoch 15/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9113 - loss: 0.2352 - val_accuracy: 0.8315 - val_loss: 0.5500
# Epoch 16/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9131 - loss: 0.2320 - val_accuracy: 0.8288 - val_loss: 0.5478
# Epoch 17/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9197 - loss: 0.2151 - val_accuracy: 0.8330 - val_loss: 0.6095
# Epoch 18/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9223 - loss: 0.2111 - val_accuracy: 0.8309 - val_loss: 0.6545
# Epoch 19/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9296 - loss: 0.1917 - val_accuracy: 0.8274 - val_loss: 0.6472
# Epoch 20/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9307 - loss: 0.1889 - val_accuracy: 0.8224 - val_loss: 0.7508
# Epoch 21/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9348 - loss: 0.1775 - val_accuracy: 0.8264 - val_loss: 0.7563
# Epoch 22/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9354 - loss: 0.1766 - val_accuracy: 0.8323 - val_loss: 0.6806
# Epoch 23/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9369 - loss: 0.1757 - val_accuracy: 0.8320 - val_loss: 0.8693
# Epoch 24/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9418 - loss: 0.1626 - val_accuracy: 0.8282 - val_loss: 0.7562
# Epoch 25/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9433 - loss: 0.1566 - val_accuracy: 0.8289 - val_loss: 0.7622
# Epoch 26/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9407 - loss: 0.1629 - val_accuracy: 0.8215 - val_loss: 0.7352
# Epoch 27/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9447 - loss: 0.1553 - val_accuracy: 0.8250 - val_loss: 0.7011
# Epoch 28/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9460 - loss: 0.1512 - val_accuracy: 0.8290 - val_loss: 0.8206
# Epoch 29/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9481 - loss: 0.1437 - val_accuracy: 0.8223 - val_loss: 1.0463
# Epoch 30/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9480 - loss: 0.1492 - val_accuracy: 0.8230 - val_loss: 1.0490
# Epoch 31/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9493 - loss: 0.1422 - val_accuracy: 0.8316 - val_loss: 0.8679
# Epoch 32/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9483 - loss: 0.1455 - val_accuracy: 0.8263 - val_loss: 0.8426
# Epoch 33/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9532 - loss: 0.1345 - val_accuracy: 0.8290 - val_loss: 0.9395
# Epoch 34/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9552 - loss: 0.1266 - val_accuracy: 0.8261 - val_loss: 0.9856
# Epoch 35/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9542 - loss: 0.1342 - val_accuracy: 0.8229 - val_loss: 0.8920
# Epoch 36/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9526 - loss: 0.1350 - val_accuracy: 0.8313 - val_loss: 0.9283
# Epoch 37/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9557 - loss: 0.1281 - val_accuracy: 0.8229 - val_loss: 0.9779
# Epoch 38/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9540 - loss: 0.1290 - val_accuracy: 0.8254 - val_loss: 0.9328
# Epoch 39/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9547 - loss: 0.1306 - val_accuracy: 0.8291 - val_loss: 0.8492
# Epoch 40/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9563 - loss: 0.1231 - val_accuracy: 0.8276 - val_loss: 0.9794
# Epoch 41/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9584 - loss: 0.1200 - val_accuracy: 0.8260 - val_loss: 1.0742
# Epoch 42/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9577 - loss: 0.1237 - val_accuracy: 0.8294 - val_loss: 1.0052
# Epoch 43/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9591 - loss: 0.1232 - val_accuracy: 0.8312 - val_loss: 0.8718
# Epoch 44/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9609 - loss: 0.1163 - val_accuracy: 0.8194 - val_loss: 1.0116
# Epoch 45/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9585 - loss: 0.1201 - val_accuracy: 0.8250 - val_loss: 1.1606
# Epoch 46/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9610 - loss: 0.1171 - val_accuracy: 0.8318 - val_loss: 0.8766
# Epoch 47/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9616 - loss: 0.1116 - val_accuracy: 0.8238 - val_loss: 1.1187
# Epoch 48/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9610 - loss: 0.1135 - val_accuracy: 0.8257 - val_loss: 0.9796
# Epoch 49/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9643 - loss: 0.1080 - val_accuracy: 0.8276 - val_loss: 0.9324
# Epoch 50/50
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9626 - loss: 0.1140 - val_accuracy: 0.8169 - val_loss: 1.0706
# 599/599 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# CNN Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.72      0.59      0.64      3963
#         GSVT       0.82      0.80      0.81      4051
#           SB       0.87      0.96      0.91      7037
#           SR       0.80      0.81      0.81      4112
#
#     accuracy                           0.82     19163
#    macro avg       0.80      0.79      0.79     19163
# weighted avg       0.81      0.82      0.81     19163
