# %%
import numpy as np
import pandas as pd
import os

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Biosppy for signal processing
from biosppy.signals import ecg

# Constants
SAMPLING_RATE = 500  # Hz
ecg_folder = "../../../../Datasets/12-lead electrocardiogram database/ECGData"
diagnostics_file = "../../../../Datasets/12-lead electrocardiogram database/Diagnostics.xlsx"

# Label mapping
rhythm_mapping = {
    'AFIB': 'AFIB',
    'AF': 'AFIB',
    'SVT': 'GSVT',
    'AT': 'GSVT',
    'SAAWR': 'GSVT',
    'ST': 'GSVT',
    'AVNRT': 'GSVT',
    'AVRT': 'GSVT',
    'SB': 'SB',
    'SR': 'SR',
    'SA': 'SR'
}


# Feature extraction function
def extract_comprehensive_features(ecg_signal):
    """
    Extract comprehensive features from entire ECG signal
    """
    try:
        ecg_processed = ecg.ecg(signal=ecg_signal, sampling_rate=SAMPLING_RATE, show=False)
        rpeaks = ecg_processed['rpeaks']
        heart_rate = ecg_processed['heart_rate']

        features = [
            np.mean(ecg_signal),
            np.std(ecg_signal),
            np.median(ecg_signal),
            np.min(ecg_signal),
            np.max(ecg_signal),
            len(rpeaks),
            np.mean(heart_rate) if len(heart_rate) > 0 else 0,
            np.std(heart_rate) if len(heart_rate) > 0 else 0,
            np.mean(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.std(np.diff(rpeaks)) if len(rpeaks) > 1 else 0,
            np.percentile(ecg_signal, 25),
            np.percentile(ecg_signal, 75),
        ]

        return features

    except Exception as e:
        print(f"Error processing signal: {e}")
        return [0] * 12


# Dataset preparation function
def prepare_dataset(ecg_folder, diagnostics_df):
    signals, signal_features, signal_labels = [], [], []

    for _, row in diagnostics_df.iterrows():
        file_name = row['FileName']
        rhythm_label = row['Rhythm']

        if pd.isnull(rhythm_label) or rhythm_label not in rhythm_mapping.values():
            continue

        ecg_file = os.path.join(ecg_folder, f"{file_name}.csv")
        if not os.path.exists(ecg_file):
            continue

        ecg_data = pd.read_csv(ecg_file, header=0).iloc[:, 1].values
        ecg_data = ecg_data.astype(float)

        features = extract_comprehensive_features(ecg_data)
        signals.append(ecg_data)
        signal_features.append(features)
        signal_labels.append(rhythm_label)

    return np.array(signals), np.array(signal_features), np.array(signal_labels)


# Load and process data
diagnostics_df = pd.read_excel(diagnostics_file)
diagnostics_df['Rhythm'] = diagnostics_df['Rhythm'].map(rhythm_mapping)

raw_signals, signal_features, signal_labels = prepare_dataset(ecg_folder, diagnostics_df)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(signal_labels)
onehot_labels = to_categorical(encoded_labels)

feature_scaler = StandardScaler()
scaled_features = feature_scaler.fit_transform(signal_features)


# Create MLP model
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model


# Stratified K-Fold Cross-Validation with optimizer tuning
optimizers = ['adam', 'sgd', 'rmsprop', 'adagrad']
results = {}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for optimizer in optimizers:
    print(f"\nTesting optimizer: {optimizer}")
    cv_scores = []

    for train_index, test_index in skf.split(scaled_features, encoded_labels):
        X_train, X_test = scaled_features[train_index], scaled_features[test_index]
        y_train, y_test = onehot_labels[train_index], onehot_labels[test_index]

        model = create_mlp_model(input_shape=X_train.shape[1], num_classes=onehot_labels.shape[1])
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_split=0.2, verbose=1)
        _, accuracy = model.evaluate(X_test, y_test, verbose=0)
        cv_scores.append(accuracy)

        y_pred = model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_test_classes = np.argmax(y_test, axis=1)

        print("\nClassification Report:")
        print(classification_report(y_test_classes, y_pred_classes, target_names=label_encoder.classes_))

    results[optimizer] = np.mean(cv_scores)
    print(f"Optimizer: {optimizer} - Mean CV Accuracy: {np.mean(cv_scores)}")

print("\nFinal Results:")
for opt, acc in results.items():
    print(f"{opt}: {acc}")
# Out:
# 2024-11-29 05:55:14.292203: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 05:55:14.303053: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 05:55:14.306343: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 05:55:14.314732: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-29 05:55:14.832415: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Testing optimizer: adam
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732838411.739296  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.771635  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.774520  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.778276  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.781038  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.783874  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.889387  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.890544  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1732838411.891738  140405 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-29 06:00:11.892803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1128 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:0e:00.0, compute capability: 8.6
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732838412.532151  143409 service.cc:146] XLA service 0x7addbc00a190 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732838412.532179  143409 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-11-29 06:00:12.561107: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-29 06:00:12.671466: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#  88/107 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5608 - loss: 1.0363
# I0000 00:00:1732838413.755878  143409 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.5872 - loss: 0.9862 - val_accuracy: 0.8281 - val_loss: 0.6029
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.8431 - loss: 0.4702 - val_accuracy: 0.8410 - val_loss: 0.5499
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.8807 - loss: 0.3693 - val_accuracy: 0.7025 - val_loss: 0.7786
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.8949 - loss: 0.3153 - val_accuracy: 0.6796 - val_loss: 0.8188
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8981 - loss: 0.2869 - val_accuracy: 0.7148 - val_loss: 0.7028
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9046 - loss: 0.2718 - val_accuracy: 0.6455 - val_loss: 0.9645
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9147 - loss: 0.2520 - val_accuracy: 0.6438 - val_loss: 0.9964
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9105 - loss: 0.2541 - val_accuracy: 0.6702 - val_loss: 0.8305
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.9136 - loss: 0.2520 - val_accuracy: 0.6432 - val_loss: 1.0561
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9215 - loss: 0.2307 - val_accuracy: 0.6596 - val_loss: 0.8559
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9179 - loss: 0.2315 - val_accuracy: 0.6661 - val_loss: 0.8408
# Epoch 12/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9251 - loss: 0.2281 - val_accuracy: 0.6379 - val_loss: 1.0378
# Epoch 13/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9242 - loss: 0.2218 - val_accuracy: 0.6596 - val_loss: 0.9125
# Epoch 14/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9276 - loss: 0.2063 - val_accuracy: 0.6385 - val_loss: 1.1164
# Epoch 15/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9316 - loss: 0.2149 - val_accuracy: 0.6772 - val_loss: 0.9149
# Epoch 16/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.9269 - loss: 0.2070 - val_accuracy: 0.6590 - val_loss: 0.9494
# Epoch 17/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9341 - loss: 0.2069 - val_accuracy: 0.6385 - val_loss: 1.1762
# Epoch 18/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.9318 - loss: 0.1969 - val_accuracy: 0.6825 - val_loss: 0.7970
# Epoch 19/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9336 - loss: 0.1966 - val_accuracy: 0.6684 - val_loss: 0.9350
# Epoch 20/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9343 - loss: 0.1957 - val_accuracy: 0.6631 - val_loss: 0.9716
# Epoch 21/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9300 - loss: 0.1912 - val_accuracy: 0.6696 - val_loss: 0.9642
# Epoch 22/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.9312 - loss: 0.2037 - val_accuracy: 0.6649 - val_loss: 0.9652
# Epoch 23/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9383 - loss: 0.1994 - val_accuracy: 0.6866 - val_loss: 0.8885
# Epoch 24/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.9340 - loss: 0.1904 - val_accuracy: 0.6508 - val_loss: 1.0159
# Epoch 25/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.9314 - loss: 0.1942 - val_accuracy: 0.6432 - val_loss: 1.1691
# Epoch 26/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9316 - loss: 0.1934 - val_accuracy: 0.6631 - val_loss: 1.0232
# Epoch 27/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9368 - loss: 0.1820 - val_accuracy: 0.6561 - val_loss: 1.0454
# Epoch 28/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9341 - loss: 0.1820 - val_accuracy: 0.6890 - val_loss: 0.8989
# Epoch 29/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9356 - loss: 0.1949 - val_accuracy: 0.6538 - val_loss: 1.0519
# Epoch 30/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9328 - loss: 0.1918 - val_accuracy: 0.6379 - val_loss: 1.1912
# Epoch 31/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9371 - loss: 0.1828 - val_accuracy: 0.6590 - val_loss: 1.0318
# Epoch 32/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9356 - loss: 0.1741 - val_accuracy: 0.6414 - val_loss: 1.0794
# Epoch 33/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9347 - loss: 0.1886 - val_accuracy: 0.6626 - val_loss: 0.9894
# Epoch 34/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9370 - loss: 0.1725 - val_accuracy: 0.6461 - val_loss: 1.0866
# Epoch 35/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9399 - loss: 0.1830 - val_accuracy: 0.6485 - val_loss: 1.1346
# Epoch 36/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9404 - loss: 0.1747 - val_accuracy: 0.6661 - val_loss: 0.9852
# Epoch 37/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9426 - loss: 0.1663 - val_accuracy: 0.6708 - val_loss: 0.9294
# Epoch 38/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9386 - loss: 0.1840 - val_accuracy: 0.6502 - val_loss: 1.1168
# Epoch 39/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9395 - loss: 0.1734 - val_accuracy: 0.6367 - val_loss: 1.3207
# Epoch 40/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9392 - loss: 0.1774 - val_accuracy: 0.6590 - val_loss: 0.9751
# Epoch 41/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9347 - loss: 0.1813 - val_accuracy: 0.6473 - val_loss: 1.0719
# Epoch 42/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9369 - loss: 0.1775 - val_accuracy: 0.6408 - val_loss: 1.2389
# Epoch 43/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9418 - loss: 0.1669 - val_accuracy: 0.6714 - val_loss: 0.9650
# Epoch 44/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9366 - loss: 0.1781 - val_accuracy: 0.6802 - val_loss: 0.9560
# Epoch 45/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9330 - loss: 0.1818 - val_accuracy: 0.6426 - val_loss: 1.1911
# Epoch 46/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9417 - loss: 0.1687 - val_accuracy: 0.6590 - val_loss: 1.0883
# Epoch 47/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.9380 - loss: 0.1710 - val_accuracy: 0.6502 - val_loss: 1.1864
# Epoch 48/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9409 - loss: 0.1794 - val_accuracy: 0.6543 - val_loss: 1.1557
# Epoch 49/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9492 - loss: 0.1421 - val_accuracy: 0.6690 - val_loss: 1.0736
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.9475 - loss: 0.1515 - val_accuracy: 0.6966 - val_loss: 1.0242
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9501 - loss: 0.1454 - val_accuracy: 0.6538 - val_loss: 1.1450
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9460 - loss: 0.1576 - val_accuracy: 0.6532 - val_loss: 1.1090
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9500 - loss: 0.1466 - val_accuracy: 0.6690 - val_loss: 1.0641
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9435 - loss: 0.1504 - val_accuracy: 0.6391 - val_loss: 1.3607
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9489 - loss: 0.1444 - val_accuracy: 0.6461 - val_loss: 1.3247
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9468 - loss: 0.1563 - val_accuracy: 0.6549 - val_loss: 1.2550
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9495 - loss: 0.1427 - val_accuracy: 0.6608 - val_loss: 1.2283
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9463 - loss: 0.1513 - val_accuracy: 0.6702 - val_loss: 1.1683
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9454 - loss: 0.1586 - val_accuracy: 0.6479 - val_loss: 1.2858
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9523 - loss: 0.1395 - val_accuracy: 0.6508 - val_loss: 1.2828
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.9472 - loss: 0.1482 - val_accuracy: 0.6414 - val_loss: 1.3393
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9445 - loss: 0.1501 - val_accuracy: 0.6485 - val_loss: 1.2393
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9540 - loss: 0.1345 - val_accuracy: 0.6426 - val_loss: 1.3308
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9492 - loss: 0.1439 - val_accuracy: 0.6790 - val_loss: 1.1799
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9497 - loss: 0.1343 - val_accuracy: 0.6309 - val_loss: 1.4231
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9463 - loss: 0.1443 - val_accuracy: 0.6502 - val_loss: 1.4147
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9502 - loss: 0.1436 - val_accuracy: 0.6309 - val_loss: 1.4910
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9453 - loss: 0.1500 - val_accuracy: 0.6819 - val_loss: 1.1783
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.72      0.86      0.78       445
#         GSVT       0.91      0.74      0.81       462
#           SB       0.97      0.99      0.98       778
#           SR       0.95      0.91      0.93       445
#
#     accuracy                           0.89      2130
#    macro avg       0.89      0.87      0.88      2130
# weighted avg       0.90      0.89      0.89      2130
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.5892 - loss: 1.0311 - val_accuracy: 0.8386 - val_loss: 0.6293
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.8688 - loss: 0.4140 - val_accuracy: 0.7283 - val_loss: 0.7924
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.8876 - loss: 0.3363 - val_accuracy: 0.6180 - val_loss: 1.1804
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8938 - loss: 0.3095 - val_accuracy: 0.7383 - val_loss: 0.7108
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9159 - loss: 0.2595 - val_accuracy: 0.6866 - val_loss: 0.8562
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9148 - loss: 0.2651 - val_accuracy: 0.6579 - val_loss: 0.9313
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9123 - loss: 0.2626 - val_accuracy: 0.6678 - val_loss: 0.8513
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9092 - loss: 0.2676 - val_accuracy: 0.6854 - val_loss: 0.8341
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9170 - loss: 0.2375 - val_accuracy: 0.6373 - val_loss: 1.1275
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9136 - loss: 0.2540 - val_accuracy: 0.6837 - val_loss: 0.8258
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9187 - loss: 0.2384 - val_accuracy: 0.6338 - val_loss: 1.2594
# Epoch 12/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9177 - loss: 0.2336 - val_accuracy: 0.6655 - val_loss: 0.9926
# Epoch 13/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9208 - loss: 0.2220 - val_accuracy: 0.6420 - val_loss: 1.2421
# Epoch 14/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9205 - loss: 0.2250 - val_accuracy: 0.6585 - val_loss: 1.0521
# Epoch 15/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9270 - loss: 0.2155 - val_accuracy: 0.6743 - val_loss: 1.0335
# Epoch 16/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9237 - loss: 0.2205 - val_accuracy: 0.6332 - val_loss: 1.2371
# Epoch 17/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.9313 - loss: 0.2061 - val_accuracy: 0.6420 - val_loss: 1.1769
# Epoch 18/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9298 - loss: 0.2123 - val_accuracy: 0.6772 - val_loss: 1.0180
# Epoch 19/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9312 - loss: 0.2094 - val_accuracy: 0.6614 - val_loss: 1.0841
# Epoch 20/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9304 - loss: 0.2015 - val_accuracy: 0.6391 - val_loss: 1.3400
# Epoch 21/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9307 - loss: 0.1991 - val_accuracy: 0.6467 - val_loss: 1.2290
# Epoch 22/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9324 - loss: 0.1988 - val_accuracy: 0.6450 - val_loss: 1.2170
# Epoch 23/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9312 - loss: 0.1985 - val_accuracy: 0.6649 - val_loss: 1.1098
# Epoch 24/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.9311 - loss: 0.1995 - val_accuracy: 0.6602 - val_loss: 1.1086
# Epoch 25/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9316 - loss: 0.1989 - val_accuracy: 0.6514 - val_loss: 1.2036
# Epoch 26/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9338 - loss: 0.2019 - val_accuracy: 0.6731 - val_loss: 1.1232
# Epoch 27/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9369 - loss: 0.1940 - val_accuracy: 0.6719 - val_loss: 1.1237
# Epoch 28/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9317 - loss: 0.1940 - val_accuracy: 0.6180 - val_loss: 1.6671
# Epoch 29/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.9272 - loss: 0.1969 - val_accuracy: 0.6432 - val_loss: 1.3090
# Epoch 30/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.9403 - loss: 0.1777 - val_accuracy: 0.6285 - val_loss: 1.4443
# Epoch 31/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.9433 - loss: 0.1759 - val_accuracy: 0.6620 - val_loss: 1.2414
# Epoch 32/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9309 - loss: 0.1937 - val_accuracy: 0.6719 - val_loss: 1.2000
# Epoch 33/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9426 - loss: 0.1710 - val_accuracy: 0.6872 - val_loss: 1.1124
# Epoch 34/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9393 - loss: 0.1853 - val_accuracy: 0.6567 - val_loss: 1.2894
# Epoch 35/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9319 - loss: 0.1851 - val_accuracy: 0.6573 - val_loss: 1.2763
# Epoch 36/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9372 - loss: 0.1766 - val_accuracy: 0.6397 - val_loss: 1.4515
# Epoch 37/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9395 - loss: 0.1785 - val_accuracy: 0.6514 - val_loss: 1.3042
# Epoch 38/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.9380 - loss: 0.1745 - val_accuracy: 0.6532 - val_loss: 1.2768
# Epoch 39/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9465 - loss: 0.1628 - val_accuracy: 0.6467 - val_loss: 1.3970
# Epoch 40/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9418 - loss: 0.1703 - val_accuracy: 0.6667 - val_loss: 1.2636
# Epoch 41/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9471 - loss: 0.1483 - val_accuracy: 0.6696 - val_loss: 1.5226
# Epoch 74/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9412 - loss: 0.1581 - val_accuracy: 0.6479 - val_loss: 1.5487
# Epoch 75/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.9408 - loss: 0.1586 - val_accuracy: 0.6766 - val_loss: 1.5778
# Epoch 76/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9465 - loss: 0.1468 - val_accuracy: 0.6702 - val_loss: 1.5480
# Epoch 77/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9430 - loss: 0.1573 - val_accuracy: 0.6631 - val_loss: 1.6001
# Epoch 78/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.9445 - loss: 0.1585 - val_accuracy: 0.7007 - val_loss: 1.4257
# Epoch 79/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.9450 - loss: 0.1500 - val_accuracy: 0.6567 - val_loss: 1.6212
# Epoch 80/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9438 - loss: 0.1608 - val_accuracy: 0.6608 - val_loss: 1.5216
# Epoch 81/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9457 - loss: 0.1500 - val_accuracy: 0.6461 - val_loss: 1.6854
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9434 - loss: 0.1608 - val_accuracy: 0.6643 - val_loss: 1.4750
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9463 - loss: 0.1425 - val_accuracy: 0.6825 - val_loss: 1.4936
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9481 - loss: 0.1561 - val_accuracy: 0.6637 - val_loss: 1.5154
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9470 - loss: 0.1609 - val_accuracy: 0.6813 - val_loss: 1.4298
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9496 - loss: 0.1478 - val_accuracy: 0.6491 - val_loss: 1.6826
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9519 - loss: 0.1424 - val_accuracy: 0.6731 - val_loss: 1.5448
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9494 - loss: 0.1455 - val_accuracy: 0.6473 - val_loss: 1.6751
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.9525 - loss: 0.1479 - val_accuracy: 0.6942 - val_loss: 1.4873
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9531 - loss: 0.1348 - val_accuracy: 0.6766 - val_loss: 1.4739
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9419 - loss: 0.1452 - val_accuracy: 0.6367 - val_loss: 1.7296
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9475 - loss: 0.1505 - val_accuracy: 0.6919 - val_loss: 1.5763
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9479 - loss: 0.1530 - val_accuracy: 0.6708 - val_loss: 1.6733
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9469 - loss: 0.1447 - val_accuracy: 0.6408 - val_loss: 1.8383
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9526 - loss: 0.1430 - val_accuracy: 0.6502 - val_loss: 1.6672
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9481 - loss: 0.1484 - val_accuracy: 0.6661 - val_loss: 1.6714
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9501 - loss: 0.1539 - val_accuracy: 0.6496 - val_loss: 1.7110
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9515 - loss: 0.1400 - val_accuracy: 0.6444 - val_loss: 1.6031
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9526 - loss: 0.1365 - val_accuracy: 0.6854 - val_loss: 1.6506
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9553 - loss: 0.1284 - val_accuracy: 0.6896 - val_loss: 1.5198
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.71      0.91      0.80       445
#         GSVT       0.94      0.73      0.82       461
#           SB       0.97      0.98      0.98       778
#           SR       0.95      0.91      0.93       445
#
#     accuracy                           0.89      2129
#    macro avg       0.90      0.88      0.88      2129
# weighted avg       0.91      0.89      0.90      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.6082 - loss: 0.9532 - val_accuracy: 0.8316 - val_loss: 0.5697
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.8666 - loss: 0.4083 - val_accuracy: 0.7881 - val_loss: 0.6418
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8823 - loss: 0.3514 - val_accuracy: 0.6796 - val_loss: 0.8713
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.8953 - loss: 0.3089 - val_accuracy: 0.6843 - val_loss: 0.7855
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9108 - loss: 0.2686 - val_accuracy: 0.7031 - val_loss: 0.7011
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9081 - loss: 0.2719 - val_accuracy: 0.6731 - val_loss: 0.7832
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9077 - loss: 0.2670 - val_accuracy: 0.6567 - val_loss: 0.9302
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9128 - loss: 0.2503 - val_accuracy: 0.7259 - val_loss: 0.7158
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9256 - loss: 0.2180 - val_accuracy: 0.6808 - val_loss: 0.8165
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9212 - loss: 0.2331 - val_accuracy: 0.6919 - val_loss: 0.7745
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9163 - loss: 0.2339 - val_accuracy: 0.6414 - val_loss: 1.1007
# Epoch 12/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9237 - loss: 0.2168 - val_accuracy: 0.6667 - val_loss: 0.8751
# Epoch 13/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9272 - loss: 0.2122 - val_accuracy: 0.6555 - val_loss: 0.9948
# Epoch 14/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9239 - loss: 0.2223 - val_accuracy: 0.6608 - val_loss: 1.0487
# Epoch 15/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9279 - loss: 0.2178 - val_accuracy: 0.6520 - val_loss: 1.0958
# Epoch 16/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9313 - loss: 0.2059 - val_accuracy: 0.6714 - val_loss: 0.9480
# Epoch 17/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9360 - loss: 0.1918 - val_accuracy: 0.6543 - val_loss: 1.0649
# Epoch 18/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9319 - loss: 0.2085 - val_accuracy: 0.6731 - val_loss: 0.9649
# Epoch 19/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9309 - loss: 0.1933 - val_accuracy: 0.6719 - val_loss: 0.9547
# Epoch 20/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9358 - loss: 0.1850 - val_accuracy: 0.7054 - val_loss: 0.7967
# Epoch 21/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9365 - loss: 0.1919 - val_accuracy: 0.6561 - val_loss: 1.0275
# Epoch 22/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9269 - loss: 0.2005 - val_accuracy: 0.6661 - val_loss: 1.0726
# Epoch 23/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9364 - loss: 0.1888 - val_accuracy: 0.6714 - val_loss: 1.0424
# Epoch 24/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9304 - loss: 0.2065 - val_accuracy: 0.6590 - val_loss: 1.0913
# Epoch 25/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.9357 - loss: 0.1784 - val_accuracy: 0.6813 - val_loss: 0.9299
# Epoch 26/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9313 - loss: 0.1863 - val_accuracy: 0.6802 - val_loss: 1.0193
# Epoch 27/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9370 - loss: 0.1817 - val_accuracy: 0.6643 - val_loss: 1.0905
# Epoch 28/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9368 - loss: 0.1821 - val_accuracy: 0.6813 - val_loss: 0.9969
# Epoch 29/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9340 - loss: 0.1821 - val_accuracy: 0.6802 - val_loss: 1.0230
# Epoch 30/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9357 - loss: 0.1847 - val_accuracy: 0.6491 - val_loss: 1.3310
# Epoch 31/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9374 - loss: 0.1812 - val_accuracy: 0.6749 - val_loss: 1.0389
# Epoch 32/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9403 - loss: 0.1700 - val_accuracy: 0.6602 - val_loss: 1.1656
# Epoch 33/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9330 - loss: 0.1810 - val_accuracy: 0.6719 - val_loss: 1.0753
# Epoch 34/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9326 - loss: 0.1851 - val_accuracy: 0.7066 - val_loss: 0.9092
# Epoch 35/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9371 - loss: 0.1764 - val_accuracy: 0.6602 - val_loss: 1.3044
# Epoch 36/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9351 - loss: 0.1822 - val_accuracy: 0.6878 - val_loss: 0.9942
# Epoch 37/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9412 - loss: 0.1711 - val_accuracy: 0.6714 - val_loss: 1.0694
# Epoch 38/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9406 - loss: 0.1753 - val_accuracy: 0.6473 - val_loss: 1.3555
# Epoch 39/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9356 - loss: 0.1832 - val_accuracy: 0.6708 - val_loss: 1.1851
# Epoch 40/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.9383 - loss: 0.1850 - val_accuracy: 0.6549 - val_loss: 1.1577
# Epoch 41/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9402 - loss: 0.1772 - val_accuracy: 0.6455 - val_loss: 1.2644
# Epoch 42/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9375 - loss: 0.1817 - val_accuracy: 0.6813 - val_loss: 1.0539
# Epoch 43/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.9419 - loss: 0.1676 - val_accuracy: 0.6491 - val_loss: 1.2579
# Epoch 44/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9451 - loss: 0.1600 - val_accuracy: 0.6643 - val_loss: 1.1678
# Epoch 45/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9439 - loss: 0.1614 - val_accuracy: 0.6796 - val_loss: 1.0574
# Epoch 46/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9431 - loss: 0.1662 - val_accuracy: 0.6655 - val_loss: 1.1386
# Epoch 47/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9420 - loss: 0.1612 - val_accuracy: 0.6579 - val_loss: 1.0951
# Epoch 48/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.9434 - loss: 0.1621 - val_accuracy: 0.6637 - val_loss: 1.2263
# Epoch 49/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9342 - loss: 0.1870 - val_accuracy: 0.6737 - val_loss: 1.1338
# Epoch 50/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9416 - loss: 0.1688 - val_accuracy: 0.6455 - val_loss: 1.3653
# Epoch 51/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9396 - loss: 0.1695 - val_accuracy: 0.6655 - val_loss: 1.0843
# Epoch 52/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9419 - loss: 0.1626 - val_accuracy: 0.6766 - val_loss: 1.1085
# Epoch 53/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.9422 - loss: 0.1637 - val_accuracy: 0.6608 - val_loss: 1.1958
# Epoch 54/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9411 - loss: 0.1561 - val_accuracy: 0.6502 - val_loss: 1.2128
# Epoch 55/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9459 - loss: 0.1532 - val_accuracy: 0.6602 - val_loss: 1.2415
# Epoch 56/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9430 - loss: 0.1560 - val_accuracy: 0.6450 - val_loss: 1.3019
# Epoch 57/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9415 - loss: 0.1556 - val_accuracy: 0.6626 - val_loss: 1.3430
# Epoch 58/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9463 - loss: 0.1530 - val_accuracy: 0.6608 - val_loss: 1.3687
# Epoch 59/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9413 - loss: 0.1621 - val_accuracy: 0.6538 - val_loss: 1.2064
# Epoch 60/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.9504 - loss: 0.1446 - val_accuracy: 0.6931 - val_loss: 1.1049
# Epoch 61/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.9405 - loss: 0.1641 - val_accuracy: 0.6643 - val_loss: 1.3398
# Epoch 62/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9484 - loss: 0.1480 - val_accuracy: 0.6585 - val_loss: 1.3963
# Epoch 63/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9462 - loss: 0.1615 - val_accuracy: 0.6714 - val_loss: 1.1479
# Epoch 64/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9406 - loss: 0.1591 - val_accuracy: 0.6984 - val_loss: 1.0316
# Epoch 65/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9397 - loss: 0.1659 - val_accuracy: 0.6849 - val_loss: 1.1403
# Epoch 66/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9483 - loss: 0.1368 - val_accuracy: 0.6843 - val_loss: 1.2416
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9460 - loss: 0.1469 - val_accuracy: 0.6579 - val_loss: 1.3197
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9466 - loss: 0.1406 - val_accuracy: 0.6637 - val_loss: 1.3326
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.67      0.89      0.77       445
#         GSVT       0.93      0.65      0.77       461
#           SB       0.97      0.98      0.97       778
#           SR       0.94      0.91      0.92       445
#
#     accuracy                           0.88      2129
#    macro avg       0.88      0.86      0.86      2129
# weighted avg       0.89      0.88      0.88      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.6680 - loss: 0.9132 - val_accuracy: 0.8239 - val_loss: 0.6665
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.8648 - loss: 0.4211 - val_accuracy: 0.6913 - val_loss: 0.8070
# Epoch 3/100
# ...
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.8642 - loss: 0.4108 - val_accuracy: 0.8163 - val_loss: 0.6221
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.8769 - loss: 0.3857 - val_accuracy: 0.8175 - val_loss: 0.6202
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.8757 - loss: 0.3921 - val_accuracy: 0.8169 - val_loss: 0.6220
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.8741 - loss: 0.3914 - val_accuracy: 0.8157 - val_loss: 0.6237
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.8668 - loss: 0.3950 - val_accuracy: 0.8175 - val_loss: 0.6203
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.8755 - loss: 0.3924 - val_accuracy: 0.8181 - val_loss: 0.6179
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8754 - loss: 0.3911 - val_accuracy: 0.8151 - val_loss: 0.6204
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.8796 - loss: 0.3821 - val_accuracy: 0.8110 - val_loss: 0.6238
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.8784 - loss: 0.3812 - val_accuracy: 0.8099 - val_loss: 0.6262
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.77      0.90      0.83       445
#         GSVT       0.87      0.84      0.85       461
#           SB       0.92      0.97      0.95       778
#           SR       0.96      0.76      0.84       445
#
#     accuracy                           0.88      2129
#    macro avg       0.88      0.86      0.87      2129
# weighted avg       0.89      0.88      0.88      2129
#
# Epoch 1/100
# /home/denuvo-drm/miniconda3/envs/CompositeADLRecognition/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.3286 - loss: 1.3407 - val_accuracy: 0.3838 - val_loss: 1.3172
# Epoch 2/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.5312 - loss: 1.2417 - val_accuracy: 0.3908 - val_loss: 1.2603
# Epoch 3/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.5529 - loss: 1.1595 - val_accuracy: 0.3950 - val_loss: 1.2142
# Epoch 4/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.5897 - loss: 1.0729 - val_accuracy: 0.3985 - val_loss: 1.1775
# Epoch 5/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.5850 - loss: 1.0108 - val_accuracy: 0.4073 - val_loss: 1.1478
# Epoch 6/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.5828 - loss: 0.9654 - val_accuracy: 0.4120 - val_loss: 1.1235
# Epoch 7/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.5998 - loss: 0.9310 - val_accuracy: 0.4196 - val_loss: 1.1031
# Epoch 8/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.6153 - loss: 0.8850 - val_accuracy: 0.4266 - val_loss: 1.0838
# Epoch 9/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.6247 - loss: 0.8559 - val_accuracy: 0.4349 - val_loss: 1.0610
# Epoch 10/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.6256 - loss: 0.8409 - val_accuracy: 0.4460 - val_loss: 1.0366
# Epoch 11/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0
100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.8176 - loss: 0.5576 - val_accuracy: 0.8210 - val_loss: 0.6084
# Epoch 44/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8226 - loss: 0.5481 - val_accuracy: 0.8204 - val_loss: 0.6056
# Epoch 45/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.8080 - loss: 0.5526 - val_accuracy: 0.8228 - val_loss: 0.6044
# Epoch 46/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.8249 - loss: 0.5598 - val_accuracy: 0.8228 - val_loss: 0.6041
# Epoch 47/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.8214 - loss: 0.5477 - val_accuracy: 0.8234 - val_loss: 0.6030
# Epoch 48/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.8233 - loss: 0.5461 - val_accuracy: 0.8239 - val_loss: 0.6008
# Epoch 49/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.8351 - loss: 0.5294 - val_accuracy: 0.8251 - val_loss: 0.6026
# Epoch 50/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8237 - loss: 0.5420 - val_accuracy: 0.8228 - val_loss: 0.6040
# Epoch 51/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.8339 - loss: 0.5210 - val_accuracy: 0.8239 - val_loss: 0.6007
# Epoch 52/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8329 - loss: 0.5146 - val_accuracy: 0.8257 - val_loss: 0.6007
# Epoch 53/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.8396 - loss: 0.5026 - val_accuracy: 0.8251 - val_loss: 0.5989
# Epoch 54/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.8351 - loss: 0.5386 - val_accuracy: 0.8257 - val_loss: 0.5972
# Epoch 55/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.8358 - loss: 0.5120 - val_accuracy: 0.8269 - val_loss: 0.5965
# Epoch 56/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8296 - loss: 0.5315 - val_accuracy: 0.8269 - val_loss: 0.5953
# Epoch 57/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.8319 - loss: 0.5292 - val_accuracy: 0.8275 - val_loss: 0.5960
# Epoch 58/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.8457 - loss: 0.4993 - val_accuracy: 0.8269 - val_loss: 0.5960
# Epoch 59/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.8326 - loss: 0.5106 - val_accuracy: 0.8269 - val_loss: 0.5994
# Epoch 60/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8384 - loss: 0.5053 - val_accuracy: 0.8275 - val_loss: 0.5998
# Epoch 61/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8335 - loss: 0.5078 - val_accuracy: 0.8286 - val_loss: 0.5965
# Epoch 62/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8409 - loss: 0.4996 - val_accuracy: 0.8292 - val_loss: 0.5965
# Epoch 63/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.8478 - loss: 0.4865 - val_accuracy: 0.8304 - val_loss: 0.5970
# Epoch 64/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.8405 - loss: 0.4989 - val_accuracy: 0.8298 - val_loss: 0.5958
# Epoch 65/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.8451 - loss: 0.5010 - val_accuracy: 0.8298 - val_loss: 0.5952
# Epoch 66/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.8429 - loss: 0.4857 - val_accuracy: 0.8292 - val_loss: 0.5972
# Epoch 67/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.8487 - loss: 0.4683 - val_accuracy: 0.8298 - val_loss: 0.5952
# Epoch 68/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.8521 - loss: 0.4670 - val_accuracy: 0.8304 - val_loss: 0.5962
# Epoch 69/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.8505 - loss: 0.4844 - val_accuracy: 0.8304 - val_loss: 0.5979
# Epoch 70/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.8514 - loss: 0.4795 - val_accuracy: 0.8316 - val_loss: 0.5980
# Epoch 71/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.8469 - loss: 0.4947 - val_accuracy: 0.8310 - val_loss: 0.6014
# Epoch 72/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.8485 - loss: 0.4750 - val_accuracy: 0.8316 - val_loss: 0.6016
# Epoch 73/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.8567 - loss: 0.4529 - val_accuracy: 0.8327 - val_loss: 0.6035
# Epoch 74/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8505 - loss: 0.4814 - val_accuracy: 0.8322 - val_loss: 0.6007
# Epoch 75/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8586 - loss: 0.4571 - val_accuracy: 0.8327 - val_loss: 0.6032
# Epoch 76/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8573 - loss: 0.4692 - val_accuracy: 0.8327 - val_loss: 0.6029
# Epoch 77/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.8498 - loss: 0.4606 - val_accuracy: 0.8322 - val_loss: 0.6044
# Epoch 78/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8593 - loss: 0.4671 - val_accuracy: 0.8322 - val_loss: 0.6051
# Epoch 79/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.8512 - loss: 0.4632 - val_accuracy: 0.8327 - val_loss: 0.6041
# Epoch 80/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.8484 - loss: 0.4677 - val_accuracy: 0.8327 - val_loss: 0.6051
# Epoch 81/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.8590 - loss: 0.4636 - val_accuracy: 0.8327 - val_loss: 0.6060
# Epoch 82/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.8519 - loss: 0.4604 - val_accuracy: 0.8304 - val_loss: 0.6077
# Epoch 83/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.8604 - loss: 0.4565 - val_accuracy: 0.8304 - val_loss: 0.6060
# Epoch 84/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.8599 - loss: 0.4603 - val_accuracy: 0.8298 - val_loss: 0.6060
# Epoch 85/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.8611 - loss: 0.4469 - val_accuracy: 0.8281 - val_loss: 0.6071
# Epoch 86/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8570 - loss: 0.4524 - val_accuracy: 0.8286 - val_loss: 0.6062
# Epoch 87/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.8620 - loss: 0.4577 - val_accuracy: 0.8275 - val_loss: 0.6076
# Epoch 88/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.8586 - loss: 0.4534 - val_accuracy: 0.8257 - val_loss: 0.6113
# Epoch 89/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.8612 - loss: 0.4333 - val_accuracy: 0.8269 - val_loss: 0.6132
# Epoch 90/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.8574 - loss: 0.4511 - val_accuracy: 0.8263 - val_loss: 0.6114
# Epoch 91/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.8534 - loss: 0.4625 - val_accuracy: 0.8251 - val_loss: 0.6108
# Epoch 92/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.8628 - loss: 0.4349 - val_accuracy: 0.8263 - val_loss: 0.6130
# Epoch 93/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.8570 - loss: 0.4674 - val_accuracy: 0.8251 - val_loss: 0.6130
# Epoch 94/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.8594 - loss: 0.4419 - val_accuracy: 0.8245 - val_loss: 0.6116
# Epoch 95/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.8672 - loss: 0.4413 - val_accuracy: 0.8228 - val_loss: 0.6135
# Epoch 96/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8708 - loss: 0.4311 - val_accuracy: 0.8234 - val_loss: 0.6132
# Epoch 97/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.8633 - loss: 0.4345 - val_accuracy: 0.8234 - val_loss: 0.6135
# Epoch 98/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.8669 - loss: 0.4386 - val_accuracy: 0.8222 - val_loss: 0.6148
# Epoch 99/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8595 - loss: 0.4446 - val_accuracy: 0.8222 - val_loss: 0.6142
# Epoch 100/100
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8666 - loss: 0.4263 - val_accuracy: 0.8228 - val_loss: 0.6131
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         AFIB       0.80      0.85      0.83       445
#         GSVT       0.87      0.86      0.86       462
#           SB       0.88      0.97      0.93       777
#           SR       0.92      0.70      0.79       445
#
#     accuracy                           0.87      2129
#    macro avg       0.87      0.85      0.85      2129
# weighted avg       0.87      0.87      0.86      2129
#
# Optimizer: adagrad - Mean CV Accuracy: 0.8751639008522034
#
# Final Results:
# adam: 0.8859661221504211
# sgd: 0.8801421523094177
# rmsprop: 0.8854031324386596
# adagrad: 0.8751639008522034
